# %%
import os
import sys
import math
import torch
import numpy as np
import matplotlib as mtp
import matplotlib.pyplot as plt

# %%
datasets_dir = os.path.join("/homeLocal/jpulzdeoliveira/datasets")
pastis_dir = os.path.join(datasets_dir, "PASTIS")
pastis_code_dir = os.path.join(datasets_dir, "PASTIS-benchmark/code")
sys.path.append(pastis_code_dir)

# %%
backend_device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {backend_device} as backend device")
# Out:
# Using cuda as backend device

# %%
os.environ["CUBLAS_WORKSPACE_CONFIG"] = ":4096:8"
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"
os.environ["TORCH_USE_CUDA_DSA"] = "1"

# %%
import geopandas as gpd
import json
from torch.utils.data import Dataset, random_split

def pre_load_data(root, split=0.95):
    print("Reading patch metadata...")
    meta_patch = gpd.read_file(os.path.join(root, "metadata.geojson"))
    meta_patch.index = meta_patch.ID_PATCH.astype(int)
    meta_patch.sort_index(inplace=True)

    print("Calculating normalization...")
    data_root = os.path.join(root, "DATA_S2")
    with open(os.path.join(root, "NORM_S2_patch.json"), 'r') as file:
        normvals = json.loads(file.read())
        folds = range(1, 6)
        means = [normvals[f"Fold_{f}"]["mean"] for f in folds]
        stds = [normvals[f"Fold_{f}"]["std"] for f in folds]
        mean = np.stack(means).mean(axis=0)
        mean = torch.from_numpy(mean).to(torch.float32)
        std = np.stack(stds).mean(axis=0)
        std = torch.from_numpy(std).to(torch.float32)
    
    print("Done.")

    split = int(len(meta_patch) * split)
    df1 = meta_patch.iloc[:split]
    df2 = meta_patch.iloc[split:]

    return (df1, df2,), (mean, std,)

class PASTISDatasetSemanticMedian(Dataset):
    def __init__(
        self,
        root,
        df,
        norm,
        num_timestamps=3,
        sampled_count=3,
        transforms=["vflip", "hflip", "rot"],
        mode="first",
        ):
        self.root = root
        self.data_root = os.path.join(root, "DATA_S2")
        self.meta_patch = df
        self.num_timestamps = num_timestamps
        self.sampled_count = sampled_count
        self.transforms = transforms
        self.mode = mode
        self.mean = norm[0]
        self.std = norm[1]

        print("Gathering patch counts...")
        self.patch_files = [] # Patch filenames
        self.selected_timestamps = [] # Num_patches*num_timestamps x sampled_count
        num_sampled = num_timestamps * sampled_count
        for patch in self.meta_patch.ID_PATCH:
            self.patch_files.append(patch)
            length = len(self.meta_patch.loc[patch]["dates-S2"])
            assert num_sampled <= length, \
                f"Number of samples {num_sampled} is bigger than number of patch timestamps {length}"
            if mode == "sampled":
                samples = np.arange(length)
                np.random.shuffle(samples)
                samples = samples[:num_sampled]
                self.selected_timestamps.extend(
                    samples.reshape((num_timestamps, sampled_count))
                    )
        self.len = len(self.patch_files) * num_timestamps

        print("Done.")
    
    def __len__(self):
        return self.len
    
    def __getitem__(self, index):
        patch = self.patch_files[index // self.num_timestamps]
        
        data = np.load(os.path.join(self.data_root, f"S2_{patch}.npy")).astype(np.float32)
        target = np.load(os.path.join(self.root, "ANNOTATIONS", f"TARGET_{patch}.npy"))

        if self.mode == "sampled":
            selected_indexes = self.selected_timestamps[index]
        elif self.mode == "random":
            samples = np.arange(data.shape[0])
            np.random.shuffle(samples)
            selected_indexes = samples[:self.sampled_count]
        elif self.mode == "first":
            offset = index % self.num_timestamps
            selected_indexes = np.arange(self.sampled_count) + offset * self.sampled_count
        data = data[selected_indexes]
        target = target[0].astype(int)
        data, target = self.augment(data, target)

        data = np.median(data, axis=0)
        data = torch.from_numpy(data)
        data = self.normalize_data(data)
        target = torch.from_numpy(target)

        return data, target

    def augment(self, data, target):
        if "hflip" in self.transforms:
            p = np.random.random_sample()
            if p > 0.5:
                data = np.flip(data, 3)
                target = np.flip(target, 1)
        if "vflip" in self.transforms:
            p = np.random.random_sample()
            if p > 0.5:
                data = np.flip(data, 2)
                target = np.flip(target, 0)
        if "rot" in self.transforms:
            rot = np.random.randint(4)
            if rot > 0:
                data = np.rot90(data, k=rot, axes=(2, 3))
                target = np.rot90(target, k=rot, axes=(0, 1))

        return (np.ascontiguousarray(data), np.ascontiguousarray(target))
    
    def normalize_data(self, data):
        return (data - self.mean[:, None, None]) / self.std[:, None, None]

class PASTISDatasetSemanticPacked(Dataset):
    def __init__(
        self,
        root,
        df,
        norm,
        pack_timestamps=1,
        mode="first" # sampled, random, first
        ):
        self.root = root
        self.data_root = os.path.join(root, "DATA_S2")
        self.meta_patch = df
        self.pack_timestamps = pack_timestamps
        self.mode = mode
        self.mean = norm[0]
        self.std = norm[1]

        print("Gathering patch counts...")
        self.patch_files = [] # Patch filenames
        self.selected_timestamps = []
        for patch in self.meta_patch.ID_PATCH:
            self.patch_files.append(patch)
            if mode == "sampled":
                length = len(self.meta_patch.loc[patch]["dates-S2"])
                self.selected_timestamps.append(np.random.randint(0, length, pack_timestamps))
        
        print("Done.")

    def __len__(self):
        return len(self.patch_files)
    
    def __getitem__(self, index):
        patch = self.patch_files[index]
        
        data = np.load(os.path.join(self.data_root, f"S2_{patch}.npy")).astype(np.float32)
        target = np.load(os.path.join(self.root, "ANNOTATIONS", f"TARGET_{patch}.npy"))

        if self.mode == "sampled":
            selected_indexes = self.selected_timestamps[index]
        elif self.mode == "random":
            selected_indexes = np.random.randint(0, data.shape[0], self.pack_timestamps)
        elif self.mode == "first":
            selected_indexes = range(self.pack_timestamps)
        data = data[selected_indexes]
        target = target[0].astype(int)
        
        data = torch.from_numpy(data)
        data = self.normalize_data(data)
        data = data.view(-1, data.shape[2], data.shape[3])
        target = torch.from_numpy(target)

        return data, target

    def normalize_data(self, data):
        return (data - self.mean[None, :, None, None]) / self.std[None, :, None, None]

def augment(data, target, transforms=['hflip', 'vflip', 'rot']):
    if 'hflip' in transforms:
        p = np.random.random_sample()
        if p >= 0.5:
            data = torch.flip(data, (3,))
            target = torch.flip(target, (2,))
    if 'vflip' in transforms:
        p = np.random.random_sample()
        if p >= 0.5:
            data = torch.flip(data, (2,))
            target = torch.flip(target, (1,))
    if "rot" in transforms:
        rot = np.random.randint(4)
        if rot > 0:
            data = torch.rot90(data, k=rot, dims=(2, 3,))
            target = torch.rot90(target, k=rot, dims=(1, 2))

    return data, target

def get_median(data, count, interval, step=0):
    timestamps = data.size(1) // 10
    length = (interval + step) * count - step

    indexes = torch.arange(length + step)
    indexes = indexes.view(count, interval + step)
    indexes  = indexes[:, :interval]
    data = data.view(data.size(0), timestamps, 10, data.size(-2), data.size(-1))
    data = data[:, indexes]
    data = data.median(1).values
    return data

# %%
(df1, df2), norm = pre_load_data(pastis_dir)

print("\nTrain dataset")
num_timestamps = 7
dataset = PASTISDatasetSemanticMedian(
    pastis_dir,
    df1,
    norm,
    num_timestamps=num_timestamps,
    sampled_count=5,
    mode="first"
    )
num_classes = 20
dataset_len = len(dataset)
print(f"Dataset len: {dataset_len}")
x, y = dataset[np.random.randint(dataset_len)]
print(x.shape)
print(y.shape)

print("\nVal dataset")
dataset_val = PASTISDatasetSemanticPacked(
    pastis_dir,
    df2,
    norm,
    pack_timestamps=32,
    mode="first"
    )
dataset_len = len(dataset_val)
print(f"Dataset len: {dataset_len}")
x, y = dataset_val[np.random.randint(dataset_len)]
print(x.shape)
print(y.shape)
# Out:
# Reading patch metadata...
# ERROR 1: PROJ: proj_create_from_database: Open of /opt/conda/share/proj failed
# Calculating normalization...
# Done.
#
# Train dataset
# Gathering patch counts...
# Done.
# Dataset len: 16177
# torch.Size([10, 128, 128])
# torch.Size([128, 128])
#
# Val dataset
# Gathering patch counts...
# Done.
# Dataset len: 122
# torch.Size([320, 128, 128])
# torch.Size([128, 128])

# %%
from matplotlib.colors import ListedColormap

cm = mtp.colormaps["tab20"]
def_colors = cm.colors
cus_colors = ['k'] + [def_colors[i] for i in range(1, 20)] + ['w']
cmap = ListedColormap(colors=cus_colors, name="agri", N=21)

def get_input_rgb(x):
    im = x[[2, 1, 0]].cpu().numpy()
    mx = im.max(axis=(1, 2))
    mi = im.min(axis=(1, 2))
    im = (im - mi[:, None, None]) / (mx - mi)[:, None, None]
    im = im.swapaxes(0, 2).swapaxes(0, 1)
    im = np.clip(im, a_max=1, a_min=0)
    return im

def plot_test(x, y):
    fix, axes = plt.subplots(1, 2, figsize=(20, 20))
    axes[0].imshow(get_input_rgb(x))
    axes[1].imshow(y.squeeze(), cmap=cmap, vmin=0, vmax=20)

#x, y, tmp = dataset[np.random.randint(dataset_len)]
#fix, axes = plt.subplots(1, dataset.sampled_count, figsize=(20, 20))
#for i in range(dataset.sampled_count):
#    t = torch.from_numpy(tmp[i])
#    axes[i].imshow(get_input_rgb(t))
#plt.show()
#plot_test(x, y)
#plt.show()

#x, y = dataset_val[np.random.randint(dataset_len)]
#x = x.unsqueeze(0)
#y = y.unsqueeze(0)
#med_count = 3
#x = get_median(x, med_count, 3, 1)
#fixa, axesa = plt.subplots(2, med_count, figsize=(med_count * 3, 6))
#fixb, axesb = plt.subplots(2, med_count, figsize=(med_count * 3, 6))
#for i in range(med_count):
#    img = x[:, i]
#    target = y.squeeze(0)
#    axesa[0, i].imshow(get_input_rgb(img.squeeze(0)))
#    axesa[0, i].axis('off')
#    axesa[1, i].imshow(target, cmap=cmap, vmin=0, vmax=20)
#    axesa[1, i].axis('off')

#    target = y
#    img, target = augment(img, target)
#    axesb[0, i].imshow(get_input_rgb(img[0]))
#    axesb[0, i].axis('off')
#    axesb[1, i].imshow(target[0], cmap=cmap, vmin=0, vmax=20)
#    axesb[1, i].axis('off')
    
#plt.show()

# %%
import multiprocessing
from torch.utils.data import DataLoader

test_split = 0.0475
n_data = len(dataset)
n_test = int(test_split * n_data)
n_train = n_data - n_test

train_set, test_set = random_split(dataset, [n_train, n_test])

batch_size = 8
num_workers = multiprocessing.cpu_count() * 2 // 5
pastis_dataloader = {
    'train': DataLoader(
        train_set,
        batch_size=batch_size,
        shuffle=True,
        num_workers=num_workers,
        pin_memory=True
    ),
    'test': DataLoader(
        test_set,
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers
    ),
    'val': DataLoader(
        dataset_val,
        batch_size=32,
        shuffle=False,
        num_workers=num_workers
    )
}

# %%
def summarize(model):
    param_size = 0
    print(
        "====================================================================\n"
        " Parameter name                        | #          | Size\n"
        "--------------------------------------------------------------------"
        )
    for name, param in model.named_parameters():
        size = param.nelement() * param.element_size()
        print(f"{name:<38} | {param.numel():10d} | {size / 1048576:.2f}MB")
        param_size += size
    buffer_size = 0
    for buffer in model.buffers():
        buffer_size += buffer.nelement() * buffer.element_size()
    print(
        "--------------------------------------------------------------------\n"
        f"Total size: {(param_size + buffer_size) / 1048576:.2f}MB\n"
        "===================================================================="
        )

# %%
# %%script true
# from tqdm import tqdm
# from sklearn.utils.class_weight import compute_class_weight
#
# targets = []
# for _, y in tqdm(pastis_dataloader['train'], desc="batches", leave=False, position=0):
#     targets.extend(y.flatten().numpy())
#
# #unique = np.bincount(targets)
# #weights = len(targets) / (20 * unique)
# #print(weights)
#
# classes = np.arange(num_classes)
# classes_weights = compute_class_weight(class_weight="balanced", classes=classes, y=targets)
# classes_weights = torch.tensor(classes_weights, dtype=torch.float32)
# classes_weights /= classes_weights.min()
# print(classes_weights)

# %%
from models.ocrnet import HRNet_Mscale
from loss.utils import get_loss
from torch import nn

hrnet_model = HRNet_Mscale(10, 1, num_classes, get_loss(num_classes)[0], crf=True)
summarize(hrnet_model)
# Out:
# Using Cross Entropy Loss
# Trunk: hrnetv2
# ====================================================================
#  Parameter name                        | #          | Size
# --------------------------------------------------------------------
# backbone.conv1.weight                  |       5760 | 0.02MB
# backbone.bn1.weight                    |         64 | 0.00MB
# backbone.bn1.bias                      |         64 | 0.00MB
# backbone.conv2.weight                  |      36864 | 0.14MB
# backbone.bn2.weight                    |         64 | 0.00MB
# backbone.bn2.bias                      |         64 | 0.00MB
# backbone.layer1.0.conv1.weight         |       4096 | 0.02MB
# backbone.layer1.0.bn1.weight           |         64 | 0.00MB
# backbone.layer1.0.bn1.bias             |         64 | 0.00MB
# backbone.layer1.0.conv2.weight         |      36864 | 0.14MB
# backbone.layer1.0.bn2.weight           |         64 | 0.00MB
# backbone.layer1.0.bn2.bias             |         64 | 0.00MB
# backbone.layer1.0.conv3.weight         |      16384 | 0.06MB
# backbone.layer1.0.bn3.weight           |        256 | 0.00MB
# backbone.layer1.0.bn3.bias             |        256 | 0.00MB
# backbone.layer1.0.downsample.0.weight  |      16384 | 0.06MB
# backbone.layer1.0.downsample.1.weight  |        256 | 0.00MB
# backbone.layer1.0.downsample.1.bias    |        256 | 0.00MB
# backbone.layer1.1.conv1.weight         |      16384 | 0.06MB
# backbone.layer1.1.bn1.weight           |         64 | 0.00MB
# backbone.layer1.1.bn1.bias             |         64 | 0.00MB
# backbone.layer1.1.conv2.weight         |      36864 | 0.14MB
# backbone.layer1.1.bn2.weight           |         64 | 0.00MB
# backbone.layer1.1.bn2.bias             |         64 | 0.00MB
# backbone.layer1.1.conv3.weight         |      16384 | 0.06MB
# backbone.layer1.1.bn3.weight           |        256 | 0.00MB
# backbone.layer1.1.bn3.bias             |        256 | 0.00MB
# backbone.layer1.2.conv1.weight         |      16384 | 0.06MB
# backbone.layer1.2.bn1.weight           |         64 | 0.00MB
# backbone.layer1.2.bn1.bias             |         64 | 0.00MB
# backbone.layer1.2.conv2.weight         |      36864 | 0.14MB
# backbone.layer1.2.bn2.weight           |         64 | 0.00MB
# backbone.layer1.2.bn2.bias             |         64 | 0.00MB
# backbone.layer1.2.conv3.weight         |      16384 | 0.06MB
# backbone.layer1.2.bn3.weight           |        256 | 0.00MB
# backbone.layer1.2.bn3.bias             |        256 | 0.00MB
# backbone.layer1.3.conv1.weight         |      16384 | 0.06MB
# backbone.layer1.3.bn1.weight           |         64 | 0.00MB
# backbone.layer1.3.bn1.bias             |         64 | 0.00MB
# backbone.layer1.3.conv2.weight         |      36864 | 0.14MB
# backbone.layer1.3.bn2.weight           |         64 | 0.00MB
# backbone.layer1.3.bn2.bias             |         64 | 0.00MB
# backbone.layer1.3.conv3.weight         |      16384 | 0.06MB
# backbone.layer1.3.bn3.weight           |        256 | 0.00MB
# backbone.layer1.3.bn3.bias             |        256 | 0.00MB
# backbone.transition1.0.0.weight        |     110592 | 0.42MB
# backbone.transition1.0.1.weight        |         48 | 0.00MB
# backbone.transition1.0.1.bias          |         48 | 0.00MB
# backbone.transition1.1.0.0.weight      |     221184 | 0.84MB
# backbone.transition1.1.0.1.weight      |         96 | 0.00MB
# backbone.transition1.1.0.1.bias        |         96 | 0.00MB
# backbone.stage2.0.branches.0.0.conv1.weight |      20736 | 0.08MB
# backbone.stage2.0.branches.0.0.bn1.weight |         48 | 0.00MB
# backbone.stage2.0.branches.0.0.bn1.bias |         48 | 0.00MB
# backbone.stage2.0.branches.0.0.conv2.weight |      20736 | 0.08MB
# backbone.stage2.0.branches.0.0.bn2.weight |         48 | 0.00MB
# backbone.stage2.0.branches.0.0.bn2.bias |         48 | 0.00MB
# backbone.stage2.0.branches.0.1.conv1.weight |      20736 | 0.08MB
# backbone.stage2.0.branches.0.1.bn1.weight |         48 | 0.00MB
# backbone.stage2.0.branches.0.1.bn1.bias |         48 | 0.00MB
# backbone.stage2.0.branches.0.1.conv2.weight |      20736 | 0.08MB
# backbone.stage2.0.branches.0.1.bn2.weight |         48 | 0.00MB
# backbone.stage2.0.branches.0.1.bn2.bias |         48 | 0.00MB
# backbone.stage2.0.branches.0.2.conv1.weight |      20736 | 0.08MB
# backbone.stage2.0.branches.0.2.bn1.weight |         48 | 0.00MB
# backbone.stage2.0.branches.0.2.bn1.bias |         48 | 0.00MB
# backbone.stage2.0.branches.0.2.conv2.weight |      20736 | 0.08MB
# backbone.stage2.0.branches.0.2.bn2.weight |         48 | 0.00MB
# backbone.stage2.0.branches.0.2.bn2.bias |         48 | 0.00MB
# backbone.stage2.0.branches.0.3.conv1.weight |      20736 | 0.08MB
# backbone.stage2.0.branches.0.3.bn1.weight |         48 | 0.00MB
# backbone.stage2.0.branches.0.3.bn1.bias |         48 | 0.00MB
# backbone.stage2.0.branches.0.3.conv2.weight |      20736 | 0.08MB
# backbone.stage2.0.branches.0.3.bn2.weight |         48 | 0.00MB
# backbone.stage2.0.branches.0.3.bn2.bias |         48 | 0.00MB
# backbone.stage2.0.branches.1.0.conv1.weight |      82944 | 0.32MB
# backbone.stage2.0.branches.1.0.bn1.weight |         96 | 0.00MB
# backbone.stage2.0.branches.1.0.bn1.bias |         96 | 0.00MB
# backbone.stage2.0.branches.1.0.conv2.weight |      82944 | 0.32MB
# backbone.stage2.0.branches.1.0.bn2.weight |         96 | 0.00MB
# backbone.stage2.0.branches.1.0.bn2.bias |         96 | 0.00MB
# backbone.stage2.0.branches.1.1.conv1.weight |      82944 | 0.32MB
# backbone.stage2.0.branches.1.1.bn1.weight |         96 | 0.00MB
# backbone.stage2.0.branches.1.1.bn1.bias |         96 | 0.00MB
# backbone.stage2.0.branches.1.1.conv2.weight |      82944 | 0.32MB
# backbone.stage2.0.branches.1.1.bn2.weight |         96 | 0.00MB
# backbone.stage2.0.branches.1.1.bn2.bias |         96 | 0.00MB
# backbone.stage2.0.branches.1.2.conv1.weight |      82944 | 0.32MB
# backbone.stage2.0.branches.1.2.bn1.weight |         96 | 0.00MB
# backbone.stage2.0.branches.1.2.bn1.bias |         96 | 0.00MB
# backbone.stage2.0.branches.1.2.conv2.weight |      82944 | 0.32MB
# backbone.stage2.0.branches.1.2.bn2.weight |         96 | 0.00MB
# backbone.stage2.0.branches.1.2.bn2.bias |         96 | 0.00MB
# backbone.stage2.0.branches.1.3.conv1.weight |      82944 | 0.32MB
# backbone.stage2.0.branches.1.3.bn1.weight |         96 | 0.00MB
# backbone.stage2.0.branches.1.3.bn1.bias |         96 | 0.00MB
# backbone.stage2.0.branches.1.3.conv2.weight |      82944 | 0.32MB
# backbone.stage2.0.branches.1.3.bn2.weight |         96 | 0.00MB
# backbone.stage2.0.branches.1.3.bn2.bias |         96 | 0.00MB
# backbone.stage2.0.fuse_layers.0.1.0.weight |       4608 | 0.02MB
# backbone.stage2.0.fuse_layers.0.1.1.weight |         48 | 0.00MB
# backbone.stage2.0.fuse_layers.0.1.1.bias |         48 | 0.00MB
# backbone.stage2.0.fuse_layers.1.0.0.0.weight |      41472 | 0.16MB
# backbone.stage2.0.fuse_layers.1.0.0.1.weight |         96 | 0.00MB
# backbone.stage2.0.fuse_layers.1.0.0.1.bias |         96 | 0.00MB
# backbone.transition2.2.0.0.weight      |     165888 | 0.63MB
# backbone.transition2.2.0.1.weight      |        192 | 0.00MB
# backbone.transition2.2.0.1.bias        |        192 | 0.00MB
# backbone.stage3.0.branches.0.0.conv1.weight |      20736 | 0.08MB
# backbone.stage3.0.branches.0.0.bn1.weight |         48 | 0.00MB
# backbone.stage3.0.branches.0.0.bn1.bias |         48 | 0.00MB
# backbone.stage3.0.branches.0.0.conv2.weight |      20736 | 0.08MB
# backbone.stage3.0.branches.0.0.bn2.weight |         48 | 0.00MB
# backbone.stage3.0.branches.0.0.bn2.bias |         48 | 0.00MB
# backbone.stage3.0.branches.0.1.conv1.weight |      20736 | 0.08MB
# backbone.stage3.0.branches.0.1.bn1.weight |         48 | 0.00MB
# backbone.stage3.0.branches.0.1.bn1.bias |         48 | 0.00MB
# backbone.stage3.0.branches.0.1.conv2.weight |      20736 | 0.08MB
# backbone.stage3.0.branches.0.1.bn2.weight |         48 | 0.00MB
# backbone.stage3.0.branches.0.1.bn2.bias |         48 | 0.00MB
# backbone.stage3.0.branches.0.2.conv1.weight |      20736 | 0.08MB
# backbone.stage3.0.branches.0.2.bn1.weight |         48 | 0.00MB
# backbone.stage3.0.branches.0.2.bn1.bias |         48 | 0.00MB
# backbone.stage3.0.branches.0.2.conv2.weight |      20736 | 0.08MB
# backbone.stage3.0.branches.0.2.bn2.weight |         48 | 0.00MB
# backbone.stage3.0.branches.0.2.bn2.bias |         48 | 0.00MB
# backbone.stage3.0.branches.0.3.conv1.weight |      20736 | 0.08MB
# backbone.stage3.0.branches.0.3.bn1.weight |         48 | 0.00MB
# backbone.stage3.0.branches.0.3.bn1.bias |         48 | 0.00MB
# backbone.stage3.0.branches.0.3.conv2.weight |      20736 | 0.08MB
# backbone.stage3.0.branches.0.3.bn2.weight |         48 | 0.00MB
# backbone.stage3.0.branches.0.3.bn2.bias |         48 | 0.00MB
# backbone.stage3.0.branches.1.0.conv1.weight |      82944 | 0.32MB
# backbone.stage3.0.branches.1.0.bn1.weight |         96 | 0.00MB
# backbone.stage3.0.branches.1.0.bn1.bias |         96 | 0.00MB
# backbone.stage3.0.branches.1.0.conv2.weight |      82944 | 0.32MB
# backbone.stage3.0.branches.1.0.bn2.weight |         96 | 0.00MB
# backbone.stage3.0.branches.1.0.bn2.bias |         96 | 0.00MB
# backbone.stage3.0.branches.1.1.conv1.weight |      82944 | 0.32MB
# backbone.stage3.0.branches.1.1.bn1.weight |         96 | 0.00MB
# backbone.stage3.0.branches.1.1.bn1.bias |         96 | 0.00MB
# backbone.stage3.0.branches.1.1.conv2.weight |      82944 | 0.32MB
# backbone.stage3.0.branches.1.1.bn2.weight |         96 | 0.00MB
# backbone.stage3.0.branches.1.1.bn2.bias |         96 | 0.00MB
# backbone.stage3.0.branches.1.2.conv1.weight |      82944 | 0.32MB
# backbone.stage3.0.branches.1.2.bn1.weight |         96 | 0.00MB
# backbone.stage3.0.branches.1.2.bn1.bias |         96 | 0.00MB
# backbone.stage3.0.branches.1.2.conv2.weight |      82944 | 0.32MB
# backbone.stage3.0.branches.1.2.bn2.weight |         96 | 0.00MB
# backbone.stage3.0.branches.1.2.bn2.bias |         96 | 0.00MB
# backbone.stage3.0.branches.1.3.conv1.weight |      82944 | 0.32MB
# backbone.stage3.0.branches.1.3.bn1.weight |         96 | 0.00MB
# backbone.stage3.0.branches.1.3.bn1.bias |         96 | 0.00MB
# backbone.stage3.0.branches.1.3.conv2.weight |      82944 | 0.32MB
# backbone.stage3.0.branches.1.3.bn2.weight |         96 | 0.00MB
# backbone.stage3.0.branches.1.3.bn2.bias |         96 | 0.00MB
# backbone.stage3.0.branches.2.0.conv1.weight |     331776 | 1.27MB
# backbone.stage3.0.branches.2.0.bn1.weight |        192 | 0.00MB
# backbone.stage3.0.branches.2.0.bn1.bias |        192 | 0.00MB
# backbone.stage3.0.branches.2.0.conv2.weight |     331776 | 1.27MB
# backbone.stage3.0.branches.2.0.bn2.weight |        192 | 0.00MB
# backbone.stage3.0.branches.2.0.bn2.bias |        192 | 0.00MB
# backbone.stage3.0.branches.2.1.conv1.weight |     331776 | 1.27MB
# backbone.stage3.0.branches.2.1.bn1.weight |        192 | 0.00MB
# backbone.stage3.0.branches.2.1.bn1.bias |        192 | 0.00MB
# backbone.stage3.0.branches.2.1.conv2.weight |     331776 | 1.27MB
# backbone.stage3.0.branches.2.1.bn2.weight |        192 | 0.00MB
# backbone.stage3.0.branches.2.1.bn2.bias |        192 | 0.00MB
# backbone.stage3.0.branches.2.2.conv1.weight |     331776 | 1.27MB
# backbone.stage3.0.branches.2.2.bn1.weight |        192 | 0.00MB
# backbone.stage3.0.branches.2.2.bn1.bias |        192 | 0.00MB
# backbone.stage3.0.branches.2.2.conv2.weight |     331776 | 1.27MB
# backbone.stage3.0.branches.2.2.bn2.weight |        192 | 0.00MB
# backbone.stage3.0.branches.2.2.bn2.bias |        192 | 0.00MB
# backbone.stage3.0.branches.2.3.conv1.weight |     331776 | 1.27MB
# backbone.stage3.0.branches.2.3.bn1.weight |        192 | 0.00MB
# backbone.stage3.0.branches.2.3.bn1.bias |        192 | 0.00MB
# backbone.stage3.0.branches.2.3.conv2.weight |     331776 | 1.27MB
# backbone.stage3.0.branches.2.3.bn2.weight |        192 | 0.00MB
# backbone.stage3.0.branches.2.3.bn2.bias |        192 | 0.00MB
# backbone.stage3.0.fuse_layers.0.1.0.weight |       4608 | 0.02MB
# backbone.stage3.0.fuse_layers.0.1.1.weight |         48 | 0.00MB
# backbone.stage3.0.fuse_layers.0.1.1.bias |         48 | 0.00MB
# backbone.stage3.0.fuse_layers.0.2.0.weight |       9216 | 0.04MB
# backbone.stage3.0.fuse_layers.0.2.1.weight |         48 | 0.00MB
# backbone.stage3.0.fuse_layers.0.2.1.bias |         48 | 0.00MB
# backbone.stage3.0.fuse_layers.1.0.0.0.weight |      41472 | 0.16MB
# backbone.stage3.0.fuse_layers.1.0.0.1.weight |         96 | 0.00MB
# backbone.stage3.0.fuse_layers.1.0.0.1.bias |         96 | 0.00MB
# backbone.stage3.0.fuse_layers.1.2.0.weight |      18432 | 0.07MB
# backbone.stage3.0.fuse_layers.1.2.1.weight |         96 | 0.00MB
# backbone.stage3.0.fuse_layers.1.2.1.bias |         96 | 0.00MB
# backbone.stage3.0.fuse_layers.2.0.0.0.weight |      20736 | 0.08MB
# backbone.stage3.0.fuse_layers.2.0.0.1.weight |         48 | 0.00MB
# backbone.stage3.0.fuse_layers.2.0.0.1.bias |         48 | 0.00MB
# backbone.stage3.0.fuse_layers.2.0.1.0.weight |      82944 | 0.32MB
# backbone.stage3.0.fuse_layers.2.0.1.1.weight |        192 | 0.00MB
# backbone.stage3.0.fuse_layers.2.0.1.1.bias |        192 | 0.00MB
# backbone.stage3.0.fuse_layers.2.1.0.0.weight |     165888 | 0.63MB
# backbone.stage3.0.fuse_layers.2.1.0.1.weight |        192 | 0.00MB
# backbone.stage3.0.fuse_layers.2.1.0.1.bias |        192 | 0.00MB
# backbone.stage3.1.branches.0.0.conv1.weight |      20736 | 0.08MB
# backbone.stage3.1.branches.0.0.bn1.weight |         48 | 0.00MB
# backbone.stage3.1.branches.0.0.bn1.bias |         48 | 0.00MB
# backbone.stage3.1.branches.0.0.conv2.weight |      20736 | 0.08MB
# backbone.stage3.1.branches.0.0.bn2.weight |         48 | 0.00MB
# backbone.stage3.1.branches.0.0.bn2.bias |         48 | 0.00MB
# backbone.stage3.1.branches.0.1.conv1.weight |      20736 | 0.08MB
# backbone.stage3.1.branches.0.1.bn1.weight |         48 | 0.00MB
# backbone.stage3.1.branches.0.1.bn1.bias |         48 | 0.00MB
# backbone.stage3.1.branches.0.1.conv2.weight |      20736 | 0.08MB
# backbone.stage3.1.branches.0.1.bn2.weight |         48 | 0.00MB
# backbone.stage3.1.branches.0.1.bn2.bias |         48 | 0.00MB
# backbone.stage3.1.branches.0.2.conv1.weight |      20736 | 0.08MB
# backbone.stage3.1.branches.0.2.bn1.weight |         48 | 0.00MB
# backbone.stage3.1.branches.0.2.bn1.bias |         48 | 0.00MB
# backbone.stage3.1.branches.0.2.conv2.weight |      20736 | 0.08MB
# backbone.stage3.1.branches.0.2.bn2.weight |         48 | 0.00MB
# backbone.stage3.1.branches.0.2.bn2.bias |         48 | 0.00MB
# backbone.stage3.1.branches.0.3.conv1.weight |      20736 | 0.08MB
# backbone.stage3.1.branches.0.3.bn1.weight |         48 | 0.00MB
# backbone.stage3.1.branches.0.3.bn1.bias |         48 | 0.00MB
# backbone.stage3.1.branches.0.3.conv2.weight |      20736 | 0.08MB
# backbone.stage3.1.branches.0.3.bn2.weight |         48 | 0.00MB
# backbone.stage3.1.branches.0.3.bn2.bias |         48 | 0.00MB
# backbone.stage3.1.branches.1.0.conv1.weight |      82944 | 0.32MB
# backbone.stage3.1.branches.1.0.bn1.weight |         96 | 0.00MB
# backbone.stage3.1.branches.1.0.bn1.bias |         96 | 0.00MB
# backbone.stage3.1.branches.1.0.conv2.weight |      82944 | 0.32MB
# backbone.stage3.1.branches.1.0.bn2.weight |         96 | 0.00MB
# backbone.stage3.1.branches.1.0.bn2.bias |         96 | 0.00MB
# backbone.stage3.1.branches.1.1.conv1.weight |      82944 | 0.32MB
# backbone.stage3.1.branches.1.1.bn1.weight |         96 | 0.00MB
# backbone.stage3.1.branches.1.1.bn1.bias |         96 | 0.00MB
# backbone.stage3.1.branches.1.1.conv2.weight |      82944 | 0.32MB
# backbone.stage3.1.branches.1.1.bn2.weight |         96 | 0.00MB
# backbone.stage3.1.branches.1.1.bn2.bias |         96 | 0.00MB
# backbone.stage3.1.branches.1.2.conv1.weight |      82944 | 0.32MB
# backbone.stage3.1.branches.1.2.bn1.weight |         96 | 0.00MB
# backbone.stage3.1.branches.1.2.bn1.bias |         96 | 0.00MB
# backbone.stage3.1.branches.1.2.conv2.weight |      82944 | 0.32MB
# backbone.stage3.1.branches.1.2.bn2.weight |         96 | 0.00MB
# backbone.stage3.1.branches.1.2.bn2.bias |         96 | 0.00MB
# backbone.stage3.1.branches.1.3.conv1.weight |      82944 | 0.32MB
# backbone.stage3.1.branches.1.3.bn1.weight |         96 | 0.00MB
# backbone.stage3.1.branches.1.3.bn1.bias |         96 | 0.00MB
# backbone.stage3.1.branches.1.3.conv2.weight |      82944 | 0.32MB
# backbone.stage3.1.branches.1.3.bn2.weight |         96 | 0.00MB
# backbone.stage3.1.branches.1.3.bn2.bias |         96 | 0.00MB
# backbone.stage3.1.branches.2.0.conv1.weight |     331776 | 1.27MB
# backbone.stage3.1.branches.2.0.bn1.weight |        192 | 0.00MB
# backbone.stage3.1.branches.2.0.bn1.bias |        192 | 0.00MB
# backbone.stage3.1.branches.2.0.conv2.weight |     331776 | 1.27MB
# backbone.stage3.1.branches.2.0.bn2.weight |        192 | 0.00MB
# backbone.stage3.1.branches.2.0.bn2.bias |        192 | 0.00MB
# backbone.stage3.1.branches.2.1.conv1.weight |     331776 | 1.27MB
# backbone.stage3.1.branches.2.1.bn1.weight |        192 | 0.00MB
# backbone.stage3.1.branches.2.1.bn1.bias |        192 | 0.00MB
# backbone.stage3.1.branches.2.1.conv2.weight |     331776 | 1.27MB
# backbone.stage3.1.branches.2.1.bn2.weight |        192 | 0.00MB
# backbone.stage3.1.branches.2.1.bn2.bias |        192 | 0.00MB
# backbone.stage3.1.branches.2.2.conv1.weight |     331776 | 1.27MB
# backbone.stage3.1.branches.2.2.bn1.weight |        192 | 0.00MB
# backbone.stage3.1.branches.2.2.bn1.bias |        192 | 0.00MB
# backbone.stage3.1.branches.2.2.conv2.weight |     331776 | 1.27MB
# backbone.stage3.1.branches.2.2.bn2.weight |        192 | 0.00MB
# backbone.stage3.1.branches.2.2.bn2.bias |        192 | 0.00MB
# backbone.stage3.1.branches.2.3.conv1.weight |     331776 | 1.27MB
# backbone.stage3.1.branches.2.3.bn1.weight |        192 | 0.00MB
# backbone.stage3.1.branches.2.3.bn1.bias |        192 | 0.00MB
# backbone.stage3.1.branches.2.3.conv2.weight |     331776 | 1.27MB
# backbone.stage3.1.branches.2.3.bn2.weight |        192 | 0.00MB
# backbone.stage3.1.branches.2.3.bn2.bias |        192 | 0.00MB
# backbone.stage3.1.fuse_layers.0.1.0.weight |       4608 | 0.02MB
# backbone.stage3.1.fuse_layers.0.1.1.weight |         48 | 0.00MB
# backbone.stage3.1.fuse_layers.0.1.1.bias |         48 | 0.00MB
# backbone.stage3.1.fuse_layers.0.2.0.weight |       9216 | 0.04MB
# backbone.stage3.1.fuse_layers.0.2.1.weight |         48 | 0.00MB
# backbone.stage3.1.fuse_layers.0.2.1.bias |         48 | 0.00MB
# backbone.stage3.1.fuse_layers.1.0.0.0.weight |      41472 | 0.16MB
# backbone.stage3.1.fuse_layers.1.0.0.1.weight |         96 | 0.00MB
# backbone.stage3.1.fuse_layers.1.0.0.1.bias |         96 | 0.00MB
# backbone.stage3.1.fuse_layers.1.2.0.weight |      18432 | 0.07MB
# backbone.stage3.1.fuse_layers.1.2.1.weight |         96 | 0.00MB
# backbone.stage3.1.fuse_layers.1.2.1.bias |         96 | 0.00MB
# backbone.stage3.1.fuse_layers.2.0.0.0.weight |      20736 | 0.08MB
# backbone.stage3.1.fuse_layers.2.0.0.1.weight |         48 | 0.00MB
# backbone.stage3.1.fuse_layers.2.0.0.1.bias |         48 | 0.00MB
# backbone.stage3.1.fuse_layers.2.0.1.0.weight |      82944 | 0.32MB
# backbone.stage3.1.fuse_layers.2.0.1.1.weight |        192 | 0.00MB
# backbone.stage3.1.fuse_layers.2.0.1.1.bias |        192 | 0.00MB
# backbone.stage3.1.fuse_layers.2.1.0.0.weight |     165888 | 0.63MB
# backbone.stage3.1.fuse_layers.2.1.0.1.weight |        192 | 0.00MB
# backbone.stage3.1.fuse_layers.2.1.0.1.bias |        192 | 0.00MB
# backbone.stage3.2.branches.0.0.conv1.weight |      20736 | 0.08MB
# backbone.stage3.2.branches.0.0.bn1.weight |         48 | 0.00MB
# backbone.stage3.2.branches.0.0.bn1.bias |         48 | 0.00MB
# backbone.stage3.2.branches.0.0.conv2.weight |      20736 | 0.08MB
# backbone.stage3.2.branches.0.0.bn2.weight |         48 | 0.00MB
# backbone.stage3.2.branches.0.0.bn2.bias |         48 | 0.00MB
# backbone.stage3.2.branches.0.1.conv1.weight |      20736 | 0.08MB
# backbone.stage3.2.branches.0.1.bn1.weight |         48 | 0.00MB
# backbone.stage3.2.branches.0.1.bn1.bias |         48 | 0.00MB
# backbone.stage3.2.branches.0.1.conv2.weight |      20736 | 0.08MB
# backbone.stage3.2.branches.0.1.bn2.weight |         48 | 0.00MB
# backbone.stage3.2.branches.0.1.bn2.bias |         48 | 0.00MB
# backbone.stage3.2.branches.0.2.conv1.weight |      20736 | 0.08MB
# backbone.stage3.2.branches.0.2.bn1.weight |         48 | 0.00MB
# backbone.stage3.2.branches.0.2.bn1.bias |         48 | 0.00MB
# backbone.stage3.2.branches.0.2.conv2.weight |      20736 | 0.08MB
# backbone.stage3.2.branches.0.2.bn2.weight |         48 | 0.00MB
# backbone.stage3.2.branches.0.2.bn2.bias |         48 | 0.00MB
# backbone.stage3.2.branches.0.3.conv1.weight |      20736 | 0.08MB
# backbone.stage3.2.branches.0.3.bn1.weight |         48 | 0.00MB
# backbone.stage3.2.branches.0.3.bn1.bias |         48 | 0.00MB
# backbone.stage3.2.branches.0.3.conv2.weight |      20736 | 0.08MB
# backbone.stage3.2.branches.0.3.bn2.weight |         48 | 0.00MB
# backbone.stage3.2.branches.0.3.bn2.bias |         48 | 0.00MB
# backbone.stage3.2.branches.1.0.conv1.weight |      82944 | 0.32MB
# backbone.stage3.2.branches.1.0.bn1.weight |         96 | 0.00MB
# backbone.stage3.2.branches.1.0.bn1.bias |         96 | 0.00MB
# backbone.stage3.2.branches.1.0.conv2.weight |      82944 | 0.32MB
# backbone.stage3.2.branches.1.0.bn2.weight |         96 | 0.00MB
# backbone.stage3.2.branches.1.0.bn2.bias |         96 | 0.00MB
# backbone.stage3.2.branches.1.1.conv1.weight |      82944 | 0.32MB
# backbone.stage3.2.branches.1.1.bn1.weight |         96 | 0.00MB
# backbone.stage3.2.branches.1.1.bn1.bias |         96 | 0.00MB
# backbone.stage3.2.branches.1.1.conv2.weight |      82944 | 0.32MB
# backbone.stage3.2.branches.1.1.bn2.weight |         96 | 0.00MB
# backbone.stage3.2.branches.1.1.bn2.bias |         96 | 0.00MB
# backbone.stage3.2.branches.1.2.conv1.weight |      82944 | 0.32MB
# backbone.stage3.2.branches.1.2.bn1.weight |         96 | 0.00MB
# backbone.stage3.2.branches.1.2.bn1.bias |         96 | 0.00MB
# backbone.stage3.2.branches.1.2.conv2.weight |      82944 | 0.32MB
# backbone.stage3.2.branches.1.2.bn2.weight |         96 | 0.00MB
# backbone.stage3.2.branches.1.2.bn2.bias |         96 | 0.00MB
# backbone.stage3.2.branches.1.3.conv1.weight |      82944 | 0.32MB
# backbone.stage3.2.branches.1.3.bn1.weight |         96 | 0.00MB
# backbone.stage3.2.branches.1.3.bn1.bias |         96 | 0.00MB
# backbone.stage3.2.branches.1.3.conv2.weight |      82944 | 0.32MB
# backbone.stage3.2.branches.1.3.bn2.weight |         96 | 0.00MB
# backbone.stage3.2.branches.1.3.bn2.bias |         96 | 0.00MB
# backbone.stage3.2.branches.2.0.conv1.weight |     331776 | 1.27MB
# backbone.stage3.2.branches.2.0.bn1.weight |        192 | 0.00MB
# backbone.stage3.2.branches.2.0.bn1.bias |        192 | 0.00MB
# backbone.stage3.2.branches.2.0.conv2.weight |     331776 | 1.27MB
# backbone.stage3.2.branches.2.0.bn2.weight |        192 | 0.00MB
# backbone.stage3.2.branches.2.0.bn2.bias |        192 | 0.00MB
# backbone.stage3.2.branches.2.1.conv1.weight |     331776 | 1.27MB
# backbone.stage3.2.branches.2.1.bn1.weight |        192 | 0.00MB
# backbone.stage3.2.branches.2.1.bn1.bias |        192 | 0.00MB
# backbone.stage3.2.branches.2.1.conv2.weight |     331776 | 1.27MB
# backbone.stage3.2.branches.2.1.bn2.weight |        192 | 0.00MB
# backbone.stage3.2.branches.2.1.bn2.bias |        192 | 0.00MB
# backbone.stage3.2.branches.2.2.conv1.weight |     331776 | 1.27MB
# backbone.stage3.2.branches.2.2.bn1.weight |        192 | 0.00MB
# backbone.stage3.2.branches.2.2.bn1.bias |        192 | 0.00MB
# backbone.stage3.2.branches.2.2.conv2.weight |     331776 | 1.27MB
# backbone.stage3.2.branches.2.2.bn2.weight |        192 | 0.00MB
# backbone.stage3.2.branches.2.2.bn2.bias |        192 | 0.00MB
# backbone.stage3.2.branches.2.3.conv1.weight |     331776 | 1.27MB
# backbone.stage3.2.branches.2.3.bn1.weight |        192 | 0.00MB
# backbone.stage3.2.branches.2.3.bn1.bias |        192 | 0.00MB
# backbone.stage3.2.branches.2.3.conv2.weight |     331776 | 1.27MB
# backbone.stage3.2.branches.2.3.bn2.weight |        192 | 0.00MB
# backbone.stage3.2.branches.2.3.bn2.bias |        192 | 0.00MB
# backbone.stage3.2.fuse_layers.0.1.0.weight |       4608 | 0.02MB
# backbone.stage3.2.fuse_layers.0.1.1.weight |         48 | 0.00MB
# backbone.stage3.2.fuse_layers.0.1.1.bias |         48 | 0.00MB
# backbone.stage3.2.fuse_layers.0.2.0.weight |       9216 | 0.04MB
# backbone.stage3.2.fuse_layers.0.2.1.weight |         48 | 0.00MB
# backbone.stage3.2.fuse_layers.0.2.1.bias |         48 | 0.00MB
# backbone.stage3.2.fuse_layers.1.0.0.0.weight |      41472 | 0.16MB
# backbone.stage3.2.fuse_layers.1.0.0.1.weight |         96 | 0.00MB
# backbone.stage3.2.fuse_layers.1.0.0.1.bias |         96 | 0.00MB
# backbone.stage3.2.fuse_layers.1.2.0.weight |      18432 | 0.07MB
# backbone.stage3.2.fuse_layers.1.2.1.weight |         96 | 0.00MB
# backbone.stage3.2.fuse_layers.1.2.1.bias |         96 | 0.00MB
# backbone.stage3.2.fuse_layers.2.0.0.0.weight |      20736 | 0.08MB
# backbone.stage3.2.fuse_layers.2.0.0.1.weight |         48 | 0.00MB
# backbone.stage3.2.fuse_layers.2.0.0.1.bias |         48 | 0.00MB
# backbone.stage3.2.fuse_layers.2.0.1.0.weight |      82944 | 0.32MB
# backbone.stage3.2.fuse_layers.2.0.1.1.weight |        192 | 0.00MB
# backbone.stage3.2.fuse_layers.2.0.1.1.bias |        192 | 0.00MB
# backbone.stage3.2.fuse_layers.2.1.0.0.weight |     165888 | 0.63MB
# backbone.stage3.2.fuse_layers.2.1.0.1.weight |        192 | 0.00MB
# backbone.stage3.2.fuse_layers.2.1.0.1.bias |        192 | 0.00MB
# backbone.stage3.3.branches.0.0.conv1.weight |      20736 | 0.08MB
# backbone.stage3.3.branches.0.0.bn1.weight |         48 | 0.00MB
# backbone.stage3.3.branches.0.0.bn1.bias |         48 | 0.00MB
# backbone.stage3.3.branches.0.0.conv2.weight |      20736 | 0.08MB
# backbone.stage3.3.branches.0.0.bn2.weight |         48 | 0.00MB
# backbone.stage3.3.branches.0.0.bn2.bias |         48 | 0.00MB
# backbone.stage3.3.branches.0.1.conv1.weight |      20736 | 0.08MB
# backbone.stage3.3.branches.0.1.bn1.weight |         48 | 0.00MB
# backbone.stage3.3.branches.0.1.bn1.bias |         48 | 0.00MB
# backbone.stage3.3.branches.0.1.conv2.weight |      20736 | 0.08MB
# backbone.stage3.3.branches.0.1.bn2.weight |         48 | 0.00MB
# backbone.stage3.3.branches.0.1.bn2.bias |         48 | 0.00MB
# backbone.stage3.3.branches.0.2.conv1.weight |      20736 | 0.08MB
# backbone.stage3.3.branches.0.2.bn1.weight |         48 | 0.00MB
# backbone.stage3.3.branches.0.2.bn1.bias |         48 | 0.00MB
# backbone.stage3.3.branches.0.2.conv2.weight |      20736 | 0.08MB
# backbone.stage3.3.branches.0.2.bn2.weight |         48 | 0.00MB
# backbone.stage3.3.branches.0.2.bn2.bias |         48 | 0.00MB
# backbone.stage3.3.branches.0.3.conv1.weight |      20736 | 0.08MB
# backbone.stage3.3.branches.0.3.bn1.weight |         48 | 0.00MB
# backbone.stage3.3.branches.0.3.bn1.bias |         48 | 0.00MB
# backbone.stage3.3.branches.0.3.conv2.weight |      20736 | 0.08MB
# backbone.stage3.3.branches.0.3.bn2.weight |         48 | 0.00MB
# backbone.stage3.3.branches.0.3.bn2.bias |         48 | 0.00MB
# backbone.stage3.3.branches.1.0.conv1.weight |      82944 | 0.32MB
# backbone.stage3.3.branches.1.0.bn1.weight |         96 | 0.00MB
# backbone.stage3.3.branches.1.0.bn1.bias |         96 | 0.00MB
# backbone.stage3.3.branches.1.0.conv2.weight |      82944 | 0.32MB
# backbone.stage3.3.branches.1.0.bn2.weight |         96 | 0.00MB
# backbone.stage3.3.branches.1.0.bn2.bias |         96 | 0.00MB
# backbone.stage3.3.branches.1.1.conv1.weight |      82944 | 0.32MB
# backbone.stage3.3.branches.1.1.bn1.weight |         96 | 0.00MB
# backbone.stage3.3.branches.1.1.bn1.bias |         96 | 0.00MB
# backbone.stage3.3.branches.1.1.conv2.weight |      82944 | 0.32MB
# backbone.stage3.3.branches.1.1.bn2.weight |         96 | 0.00MB
# backbone.stage3.3.branches.1.1.bn2.bias |         96 | 0.00MB
# backbone.stage3.3.branches.1.2.conv1.weight |      82944 | 0.32MB
# backbone.stage3.3.branches.1.2.bn1.weight |         96 | 0.00MB
# backbone.stage3.3.branches.1.2.bn1.bias |         96 | 0.00MB
# backbone.stage3.3.branches.1.2.conv2.weight |      82944 | 0.32MB
# backbone.stage3.3.branches.1.2.bn2.weight |         96 | 0.00MB
# backbone.stage3.3.branches.1.2.bn2.bias |         96 | 0.00MB
# backbone.stage3.3.branches.1.3.conv1.weight |      82944 | 0.32MB
# backbone.stage3.3.branches.1.3.bn1.weight |         96 | 0.00MB
# backbone.stage3.3.branches.1.3.bn1.bias |         96 | 0.00MB
# backbone.stage3.3.branches.1.3.conv2.weight |      82944 | 0.32MB
# backbone.stage3.3.branches.1.3.bn2.weight |         96 | 0.00MB
# backbone.stage3.3.branches.1.3.bn2.bias |         96 | 0.00MB
# backbone.stage3.3.branches.2.0.conv1.weight |     331776 | 1.27MB
# backbone.stage3.3.branches.2.0.bn1.weight |        192 | 0.00MB
# backbone.stage3.3.branches.2.0.bn1.bias |        192 | 0.00MB
# backbone.stage3.3.branches.2.0.conv2.weight |     331776 | 1.27MB
# backbone.stage3.3.branches.2.0.bn2.weight |        192 | 0.00MB
# backbone.stage3.3.branches.2.0.bn2.bias |        192 | 0.00MB
# backbone.stage3.3.branches.2.1.conv1.weight |     331776 | 1.27MB
# backbone.stage3.3.branches.2.1.bn1.weight |        192 | 0.00MB
# backbone.stage3.3.branches.2.1.bn1.bias |        192 | 0.00MB
# backbone.stage3.3.branches.2.1.conv2.weight |     331776 | 1.27MB
# backbone.stage3.3.branches.2.1.bn2.weight |        192 | 0.00MB
# backbone.stage3.3.branches.2.1.bn2.bias |        192 | 0.00MB
# backbone.stage3.3.branches.2.2.conv1.weight |     331776 | 1.27MB
# backbone.stage3.3.branches.2.2.bn1.weight |        192 | 0.00MB
# backbone.stage3.3.branches.2.2.bn1.bias |        192 | 0.00MB
# backbone.stage3.3.branches.2.2.conv2.weight |     331776 | 1.27MB
# backbone.stage3.3.branches.2.2.bn2.weight |        192 | 0.00MB
# backbone.stage3.3.branches.2.2.bn2.bias |        192 | 0.00MB
# backbone.stage3.3.branches.2.3.conv1.weight |     331776 | 1.27MB
# backbone.stage3.3.branches.2.3.bn1.weight |        192 | 0.00MB
# backbone.stage3.3.branches.2.3.bn1.bias |        192 | 0.00MB
# backbone.stage3.3.branches.2.3.conv2.weight |     331776 | 1.27MB
# backbone.stage3.3.branches.2.3.bn2.weight |        192 | 0.00MB
# backbone.stage3.3.branches.2.3.bn2.bias |        192 | 0.00MB
# backbone.stage3.3.fuse_layers.0.1.0.weight |       4608 | 0.02MB
# backbone.stage3.3.fuse_layers.0.1.1.weight |         48 | 0.00MB
# backbone.stage3.3.fuse_layers.0.1.1.bias |         48 | 0.00MB
# backbone.stage3.3.fuse_layers.0.2.0.weight |       9216 | 0.04MB
# backbone.stage3.3.fuse_layers.0.2.1.weight |         48 | 0.00MB
# backbone.stage3.3.fuse_layers.0.2.1.bias |         48 | 0.00MB
# backbone.stage3.3.fuse_layers.1.0.0.0.weight |      41472 | 0.16MB
# backbone.stage3.3.fuse_layers.1.0.0.1.weight |         96 | 0.00MB
# backbone.stage3.3.fuse_layers.1.0.0.1.bias |         96 | 0.00MB
# backbone.stage3.3.fuse_layers.1.2.0.weight |      18432 | 0.07MB
# backbone.stage3.3.fuse_layers.1.2.1.weight |         96 | 0.00MB
# backbone.stage3.3.fuse_layers.1.2.1.bias |         96 | 0.00MB
# backbone.stage3.3.fuse_layers.2.0.0.0.weight |      20736 | 0.08MB
# backbone.stage3.3.fuse_layers.2.0.0.1.weight |         48 | 0.00MB
# backbone.stage3.3.fuse_layers.2.0.0.1.bias |         48 | 0.00MB
# backbone.stage3.3.fuse_layers.2.0.1.0.weight |      82944 | 0.32MB
# backbone.stage3.3.fuse_layers.2.0.1.1.weight |        192 | 0.00MB
# backbone.stage3.3.fuse_layers.2.0.1.1.bias |        192 | 0.00MB
# backbone.stage3.3.fuse_layers.2.1.0.0.weight |     165888 | 0.63MB
# backbone.stage3.3.fuse_layers.2.1.0.1.weight |        192 | 0.00MB
# backbone.stage3.3.fuse_layers.2.1.0.1.bias |        192 | 0.00MB
# backbone.transition3.3.0.0.weight      |     663552 | 2.53MB
# backbone.transition3.3.0.1.weight      |        384 | 0.00MB
# backbone.transition3.3.0.1.bias        |        384 | 0.00MB
# backbone.stage4.0.branches.0.0.conv1.weight |      20736 | 0.08MB
# backbone.stage4.0.branches.0.0.bn1.weight |         48 | 0.00MB
# backbone.stage4.0.branches.0.0.bn1.bias |         48 | 0.00MB
# backbone.stage4.0.branches.0.0.conv2.weight |      20736 | 0.08MB
# backbone.stage4.0.branches.0.0.bn2.weight |         48 | 0.00MB
# backbone.stage4.0.branches.0.0.bn2.bias |         48 | 0.00MB
# backbone.stage4.0.branches.0.1.conv1.weight |      20736 | 0.08MB
# backbone.stage4.0.branches.0.1.bn1.weight |         48 | 0.00MB
# backbone.stage4.0.branches.0.1.bn1.bias |         48 | 0.00MB
# backbone.stage4.0.branches.0.1.conv2.weight |      20736 | 0.08MB
# backbone.stage4.0.branches.0.1.bn2.weight |         48 | 0.00MB
# backbone.stage4.0.branches.0.1.bn2.bias |         48 | 0.00MB
# backbone.stage4.0.branches.0.2.conv1.weight |      20736 | 0.08MB
# backbone.stage4.0.branches.0.2.bn1.weight |         48 | 0.00MB
# backbone.stage4.0.branches.0.2.bn1.bias |         48 | 0.00MB
# backbone.stage4.0.branches.0.2.conv2.weight |      20736 | 0.08MB
# backbone.stage4.0.branches.0.2.bn2.weight |         48 | 0.00MB
# backbone.stage4.0.branches.0.2.bn2.bias |         48 | 0.00MB
# backbone.stage4.0.branches.0.3.conv1.weight |      20736 | 0.08MB
# backbone.stage4.0.branches.0.3.bn1.weight |         48 | 0.00MB
# backbone.stage4.0.branches.0.3.bn1.bias |         48 | 0.00MB
# backbone.stage4.0.branches.0.3.conv2.weight |      20736 | 0.08MB
# backbone.stage4.0.branches.0.3.bn2.weight |         48 | 0.00MB
# backbone.stage4.0.branches.0.3.bn2.bias |         48 | 0.00MB
# backbone.stage4.0.branches.1.0.conv1.weight |      82944 | 0.32MB
# backbone.stage4.0.branches.1.0.bn1.weight |         96 | 0.00MB
# backbone.stage4.0.branches.1.0.bn1.bias |         96 | 0.00MB
# backbone.stage4.0.branches.1.0.conv2.weight |      82944 | 0.32MB
# backbone.stage4.0.branches.1.0.bn2.weight |         96 | 0.00MB
# backbone.stage4.0.branches.1.0.bn2.bias |         96 | 0.00MB
# backbone.stage4.0.branches.1.1.conv1.weight |      82944 | 0.32MB
# backbone.stage4.0.branches.1.1.bn1.weight |         96 | 0.00MB
# backbone.stage4.0.branches.1.1.bn1.bias |         96 | 0.00MB
# backbone.stage4.0.branches.1.1.conv2.weight |      82944 | 0.32MB
# backbone.stage4.0.branches.1.1.bn2.weight |         96 | 0.00MB
# backbone.stage4.0.branches.1.1.bn2.bias |         96 | 0.00MB
# backbone.stage4.0.branches.1.2.conv1.weight |      82944 | 0.32MB
# backbone.stage4.0.branches.1.2.bn1.weight |         96 | 0.00MB
# backbone.stage4.0.branches.1.2.bn1.bias |         96 | 0.00MB
# backbone.stage4.0.branches.1.2.conv2.weight |      82944 | 0.32MB
# backbone.stage4.0.branches.1.2.bn2.weight |         96 | 0.00MB
# backbone.stage4.0.branches.1.2.bn2.bias |         96 | 0.00MB
# backbone.stage4.0.branches.1.3.conv1.weight |      82944 | 0.32MB
# backbone.stage4.0.branches.1.3.bn1.weight |         96 | 0.00MB
# backbone.stage4.0.branches.1.3.bn1.bias |         96 | 0.00MB
# backbone.stage4.0.branches.1.3.conv2.weight |      82944 | 0.32MB
# backbone.stage4.0.branches.1.3.bn2.weight |         96 | 0.00MB
# backbone.stage4.0.branches.1.3.bn2.bias |         96 | 0.00MB
# backbone.stage4.0.branches.2.0.conv1.weight |     331776 | 1.27MB
# backbone.stage4.0.branches.2.0.bn1.weight |        192 | 0.00MB
# backbone.stage4.0.branches.2.0.bn1.bias |        192 | 0.00MB
# backbone.stage4.0.branches.2.0.conv2.weight |     331776 | 1.27MB
# backbone.stage4.0.branches.2.0.bn2.weight |        192 | 0.00MB
# backbone.stage4.0.branches.2.0.bn2.bias |        192 | 0.00MB
# backbone.stage4.0.branches.2.1.conv1.weight |     331776 | 1.27MB
# backbone.stage4.0.branches.2.1.bn1.weight |        192 | 0.00MB
# backbone.stage4.0.branches.2.1.bn1.bias |        192 | 0.00MB
# backbone.stage4.0.branches.2.1.conv2.weight |     331776 | 1.27MB
# backbone.stage4.0.branches.2.1.bn2.weight |        192 | 0.00MB
# backbone.stage4.0.branches.2.1.bn2.bias |        192 | 0.00MB
# backbone.stage4.0.branches.2.2.conv1.weight |     331776 | 1.27MB
# backbone.stage4.0.branches.2.2.bn1.weight |        192 | 0.00MB
# backbone.stage4.0.branches.2.2.bn1.bias |        192 | 0.00MB
# backbone.stage4.0.branches.2.2.conv2.weight |     331776 | 1.27MB
# backbone.stage4.0.branches.2.2.bn2.weight |        192 | 0.00MB
# backbone.stage4.0.branches.2.2.bn2.bias |        192 | 0.00MB
# backbone.stage4.0.branches.2.3.conv1.weight |     331776 | 1.27MB
# backbone.stage4.0.branches.2.3.bn1.weight |        192 | 0.00MB
# backbone.stage4.0.branches.2.3.bn1.bias |        192 | 0.00MB
# backbone.stage4.0.branches.2.3.conv2.weight |     331776 | 1.27MB
# backbone.stage4.0.branches.2.3.bn2.weight |        192 | 0.00MB
# backbone.stage4.0.branches.2.3.bn2.bias |        192 | 0.00MB
# backbone.stage4.0.branches.3.0.conv1.weight |    1327104 | 5.06MB
# backbone.stage4.0.branches.3.0.bn1.weight |        384 | 0.00MB
# backbone.stage4.0.branches.3.0.bn1.bias |        384 | 0.00MB
# backbone.stage4.0.branches.3.0.conv2.weight |    1327104 | 5.06MB
# backbone.stage4.0.branches.3.0.bn2.weight |        384 | 0.00MB
# backbone.stage4.0.branches.3.0.bn2.bias |        384 | 0.00MB
# backbone.stage4.0.branches.3.1.conv1.weight |    1327104 | 5.06MB
# backbone.stage4.0.branches.3.1.bn1.weight |        384 | 0.00MB
# backbone.stage4.0.branches.3.1.bn1.bias |        384 | 0.00MB
# backbone.stage4.0.branches.3.1.conv2.weight |    1327104 | 5.06MB
# backbone.stage4.0.branches.3.1.bn2.weight |        384 | 0.00MB
# backbone.stage4.0.branches.3.1.bn2.bias |        384 | 0.00MB
# backbone.stage4.0.branches.3.2.conv1.weight |    1327104 | 5.06MB
# backbone.stage4.0.branches.3.2.bn1.weight |        384 | 0.00MB
# backbone.stage4.0.branches.3.2.bn1.bias |        384 | 0.00MB
# backbone.stage4.0.branches.3.2.conv2.weight |    1327104 | 5.06MB
# backbone.stage4.0.branches.3.2.bn2.weight |        384 | 0.00MB
# backbone.stage4.0.branches.3.2.bn2.bias |        384 | 0.00MB
# backbone.stage4.0.branches.3.3.conv1.weight |    1327104 | 5.06MB
# backbone.stage4.0.branches.3.3.bn1.weight |        384 | 0.00MB
# backbone.stage4.0.branches.3.3.bn1.bias |        384 | 0.00MB
# backbone.stage4.0.branches.3.3.conv2.weight |    1327104 | 5.06MB
# backbone.stage4.0.branches.3.3.bn2.weight |        384 | 0.00MB
# backbone.stage4.0.branches.3.3.bn2.bias |        384 | 0.00MB
# backbone.stage4.0.fuse_layers.0.1.0.weight |       4608 | 0.02MB
# backbone.stage4.0.fuse_layers.0.1.1.weight |         48 | 0.00MB
# backbone.stage4.0.fuse_layers.0.1.1.bias |         48 | 0.00MB
# backbone.stage4.0.fuse_layers.0.2.0.weight |       9216 | 0.04MB
# backbone.stage4.0.fuse_layers.0.2.1.weight |         48 | 0.00MB
# backbone.stage4.0.fuse_layers.0.2.1.bias |         48 | 0.00MB
# backbone.stage4.0.fuse_layers.0.3.0.weight |      18432 | 0.07MB
# backbone.stage4.0.fuse_layers.0.3.1.weight |         48 | 0.00MB
# backbone.stage4.0.fuse_layers.0.3.1.bias |         48 | 0.00MB
# backbone.stage4.0.fuse_layers.1.0.0.0.weight |      41472 | 0.16MB
# backbone.stage4.0.fuse_layers.1.0.0.1.weight |         96 | 0.00MB
# backbone.stage4.0.fuse_layers.1.0.0.1.bias |         96 | 0.00MB
# backbone.stage4.0.fuse_layers.1.2.0.weight |      18432 | 0.07MB
# backbone.stage4.0.fuse_layers.1.2.1.weight |         96 | 0.00MB
# backbone.stage4.0.fuse_layers.1.2.1.bias |         96 | 0.00MB
# backbone.stage4.0.fuse_layers.1.3.0.weight |      36864 | 0.14MB
# backbone.stage4.0.fuse_layers.1.3.1.weight |         96 | 0.00MB
# backbone.stage4.0.fuse_layers.1.3.1.bias |         96 | 0.00MB
# backbone.stage4.0.fuse_layers.2.0.0.0.weight |      20736 | 0.08MB
# backbone.stage4.0.fuse_layers.2.0.0.1.weight |         48 | 0.00MB
# backbone.stage4.0.fuse_layers.2.0.0.1.bias |         48 | 0.00MB
# backbone.stage4.0.fuse_layers.2.0.1.0.weight |      82944 | 0.32MB
# backbone.stage4.0.fuse_layers.2.0.1.1.weight |        192 | 0.00MB
# backbone.stage4.0.fuse_layers.2.0.1.1.bias |        192 | 0.00MB
# backbone.stage4.0.fuse_layers.2.1.0.0.weight |     165888 | 0.63MB
# backbone.stage4.0.fuse_layers.2.1.0.1.weight |        192 | 0.00MB
# backbone.stage4.0.fuse_layers.2.1.0.1.bias |        192 | 0.00MB
# backbone.stage4.0.fuse_layers.2.3.0.weight |      73728 | 0.28MB
# backbone.stage4.0.fuse_layers.2.3.1.weight |        192 | 0.00MB
# backbone.stage4.0.fuse_layers.2.3.1.bias |        192 | 0.00MB
# backbone.stage4.0.fuse_layers.3.0.0.0.weight |      20736 | 0.08MB
# backbone.stage4.0.fuse_layers.3.0.0.1.weight |         48 | 0.00MB
# backbone.stage4.0.fuse_layers.3.0.0.1.bias |         48 | 0.00MB
# backbone.stage4.0.fuse_layers.3.0.1.0.weight |      20736 | 0.08MB
# backbone.stage4.0.fuse_layers.3.0.1.1.weight |         48 | 0.00MB
# backbone.stage4.0.fuse_layers.3.0.1.1.bias |         48 | 0.00MB
# backbone.stage4.0.fuse_layers.3.0.2.0.weight |     165888 | 0.63MB
# backbone.stage4.0.fuse_layers.3.0.2.1.weight |        384 | 0.00MB
# backbone.stage4.0.fuse_layers.3.0.2.1.bias |        384 | 0.00MB
# backbone.stage4.0.fuse_layers.3.1.0.0.weight |      82944 | 0.32MB
# backbone.stage4.0.fuse_layers.3.1.0.1.weight |         96 | 0.00MB
# backbone.stage4.0.fuse_layers.3.1.0.1.bias |         96 | 0.00MB
# backbone.stage4.0.fuse_layers.3.1.1.0.weight |     331776 | 1.27MB
# backbone.stage4.0.fuse_layers.3.1.1.1.weight |        384 | 0.00MB
# backbone.stage4.0.fuse_layers.3.1.1.1.bias |        384 | 0.00MB
# backbone.stage4.0.fuse_layers.3.2.0.0.weight |     663552 | 2.53MB
# backbone.stage4.0.fuse_layers.3.2.0.1.weight |        384 | 0.00MB
# backbone.stage4.0.fuse_layers.3.2.0.1.bias |        384 | 0.00MB
# backbone.stage4.1.branches.0.0.conv1.weight |      20736 | 0.08MB
# backbone.stage4.1.branches.0.0.bn1.weight |         48 | 0.00MB
# backbone.stage4.1.branches.0.0.bn1.bias |         48 | 0.00MB
# backbone.stage4.1.branches.0.0.conv2.weight |      20736 | 0.08MB
# backbone.stage4.1.branches.0.0.bn2.weight |         48 | 0.00MB
# backbone.stage4.1.branches.0.0.bn2.bias |         48 | 0.00MB
# backbone.stage4.1.branches.0.1.conv1.weight |      20736 | 0.08MB
# backbone.stage4.1.branches.0.1.bn1.weight |         48 | 0.00MB
# backbone.stage4.1.branches.0.1.bn1.bias |         48 | 0.00MB
# backbone.stage4.1.branches.0.1.conv2.weight |      20736 | 0.08MB
# backbone.stage4.1.branches.0.1.bn2.weight |         48 | 0.00MB
# backbone.stage4.1.branches.0.1.bn2.bias |         48 | 0.00MB
# backbone.stage4.1.branches.0.2.conv1.weight |      20736 | 0.08MB
# backbone.stage4.1.branches.0.2.bn1.weight |         48 | 0.00MB
# backbone.stage4.1.branches.0.2.bn1.bias |         48 | 0.00MB
# backbone.stage4.1.branches.0.2.conv2.weight |      20736 | 0.08MB
# backbone.stage4.1.branches.0.2.bn2.weight |         48 | 0.00MB
# backbone.stage4.1.branches.0.2.bn2.bias |         48 | 0.00MB
# backbone.stage4.1.branches.0.3.conv1.weight |      20736 | 0.08MB
# backbone.stage4.1.branches.0.3.bn1.weight |         48 | 0.00MB
# backbone.stage4.1.branches.0.3.bn1.bias |         48 | 0.00MB
# backbone.stage4.1.branches.0.3.conv2.weight |      20736 | 0.08MB
# backbone.stage4.1.branches.0.3.bn2.weight |         48 | 0.00MB
# backbone.stage4.1.branches.0.3.bn2.bias |         48 | 0.00MB
# backbone.stage4.1.branches.1.0.conv1.weight |      82944 | 0.32MB
# backbone.stage4.1.branches.1.0.bn1.weight |         96 | 0.00MB
# backbone.stage4.1.branches.1.0.bn1.bias |         96 | 0.00MB
# backbone.stage4.1.branches.1.0.conv2.weight |      82944 | 0.32MB
# backbone.stage4.1.branches.1.0.bn2.weight |         96 | 0.00MB
# backbone.stage4.1.branches.1.0.bn2.bias |         96 | 0.00MB
# backbone.stage4.1.branches.1.1.conv1.weight |      82944 | 0.32MB
# backbone.stage4.1.branches.1.1.bn1.weight |         96 | 0.00MB
# backbone.stage4.1.branches.1.1.bn1.bias |         96 | 0.00MB
# backbone.stage4.1.branches.1.1.conv2.weight |      82944 | 0.32MB
# backbone.stage4.1.branches.1.1.bn2.weight |         96 | 0.00MB
# backbone.stage4.1.branches.1.1.bn2.bias |         96 | 0.00MB
# backbone.stage4.1.branches.1.2.conv1.weight |      82944 | 0.32MB
# backbone.stage4.1.branches.1.2.bn1.weight |         96 | 0.00MB
# backbone.stage4.1.branches.1.2.bn1.bias |         96 | 0.00MB
# backbone.stage4.1.branches.1.2.conv2.weight |      82944 | 0.32MB
# backbone.stage4.1.branches.1.2.bn2.weight |         96 | 0.00MB
# backbone.stage4.1.branches.1.2.bn2.bias |         96 | 0.00MB
# backbone.stage4.1.branches.1.3.conv1.weight |      82944 | 0.32MB
# backbone.stage4.1.branches.1.3.bn1.weight |         96 | 0.00MB
# backbone.stage4.1.branches.1.3.bn1.bias |         96 | 0.00MB
# backbone.stage4.1.branches.1.3.conv2.weight |      82944 | 0.32MB
# backbone.stage4.1.branches.1.3.bn2.weight |         96 | 0.00MB
# backbone.stage4.1.branches.1.3.bn2.bias |         96 | 0.00MB
# backbone.stage4.1.branches.2.0.conv1.weight |     331776 | 1.27MB
# backbone.stage4.1.branches.2.0.bn1.weight |        192 | 0.00MB
# backbone.stage4.1.branches.2.0.bn1.bias |        192 | 0.00MB
# backbone.stage4.1.branches.2.0.conv2.weight |     331776 | 1.27MB
# backbone.stage4.1.branches.2.0.bn2.weight |        192 | 0.00MB
# backbone.stage4.1.branches.2.0.bn2.bias |        192 | 0.00MB
# backbone.stage4.1.branches.2.1.conv1.weight |     331776 | 1.27MB
# backbone.stage4.1.branches.2.1.bn1.weight |        192 | 0.00MB
# backbone.stage4.1.branches.2.1.bn1.bias |        192 | 0.00MB
# backbone.stage4.1.branches.2.1.conv2.weight |     331776 | 1.27MB
# backbone.stage4.1.branches.2.1.bn2.weight |        192 | 0.00MB
# backbone.stage4.1.branches.2.1.bn2.bias |        192 | 0.00MB
# backbone.stage4.1.branches.2.2.conv1.weight |     331776 | 1.27MB
# backbone.stage4.1.branches.2.2.bn1.weight |        192 | 0.00MB
# backbone.stage4.1.branches.2.2.bn1.bias |        192 | 0.00MB
# backbone.stage4.1.branches.2.2.conv2.weight |     331776 | 1.27MB
# backbone.stage4.1.branches.2.2.bn2.weight |        192 | 0.00MB
# backbone.stage4.1.branches.2.2.bn2.bias |        192 | 0.00MB
# backbone.stage4.1.branches.2.3.conv1.weight |     331776 | 1.27MB
# backbone.stage4.1.branches.2.3.bn1.weight |        192 | 0.00MB
# backbone.stage4.1.branches.2.3.bn1.bias |        192 | 0.00MB
# backbone.stage4.1.branches.2.3.conv2.weight |     331776 | 1.27MB
# backbone.stage4.1.branches.2.3.bn2.weight |        192 | 0.00MB
# backbone.stage4.1.branches.2.3.bn2.bias |        192 | 0.00MB
# backbone.stage4.1.branches.3.0.conv1.weight |    1327104 | 5.06MB
# backbone.stage4.1.branches.3.0.bn1.weight |        384 | 0.00MB
# backbone.stage4.1.branches.3.0.bn1.bias |        384 | 0.00MB
# backbone.stage4.1.branches.3.0.conv2.weight |    1327104 | 5.06MB
# backbone.stage4.1.branches.3.0.bn2.weight |        384 | 0.00MB
# backbone.stage4.1.branches.3.0.bn2.bias |        384 | 0.00MB
# backbone.stage4.1.branches.3.1.conv1.weight |    1327104 | 5.06MB
# backbone.stage4.1.branches.3.1.bn1.weight |        384 | 0.00MB
# backbone.stage4.1.branches.3.1.bn1.bias |        384 | 0.00MB
# backbone.stage4.1.branches.3.1.conv2.weight |    1327104 | 5.06MB
# backbone.stage4.1.branches.3.1.bn2.weight |        384 | 0.00MB
# backbone.stage4.1.branches.3.1.bn2.bias |        384 | 0.00MB
# backbone.stage4.1.branches.3.2.conv1.weight |    1327104 | 5.06MB
# backbone.stage4.1.branches.3.2.bn1.weight |        384 | 0.00MB
# backbone.stage4.1.branches.3.2.bn1.bias |        384 | 0.00MB
# backbone.stage4.1.branches.3.2.conv2.weight |    1327104 | 5.06MB
# backbone.stage4.1.branches.3.2.bn2.weight |        384 | 0.00MB
# backbone.stage4.1.branches.3.2.bn2.bias |        384 | 0.00MB
# backbone.stage4.1.branches.3.3.conv1.weight |    1327104 | 5.06MB
# backbone.stage4.1.branches.3.3.bn1.weight |        384 | 0.00MB
# backbone.stage4.1.branches.3.3.bn1.bias |        384 | 0.00MB
# backbone.stage4.1.branches.3.3.conv2.weight |    1327104 | 5.06MB
# backbone.stage4.1.branches.3.3.bn2.weight |        384 | 0.00MB
# backbone.stage4.1.branches.3.3.bn2.bias |        384 | 0.00MB
# backbone.stage4.1.fuse_layers.0.1.0.weight |       4608 | 0.02MB
# backbone.stage4.1.fuse_layers.0.1.1.weight |         48 | 0.00MB
# backbone.stage4.1.fuse_layers.0.1.1.bias |         48 | 0.00MB
# backbone.stage4.1.fuse_layers.0.2.0.weight |       9216 | 0.04MB
# backbone.stage4.1.fuse_layers.0.2.1.weight |         48 | 0.00MB
# backbone.stage4.1.fuse_layers.0.2.1.bias |         48 | 0.00MB
# backbone.stage4.1.fuse_layers.0.3.0.weight |      18432 | 0.07MB
# backbone.stage4.1.fuse_layers.0.3.1.weight |         48 | 0.00MB
# backbone.stage4.1.fuse_layers.0.3.1.bias |         48 | 0.00MB
# backbone.stage4.1.fuse_layers.1.0.0.0.weight |      41472 | 0.16MB
# backbone.stage4.1.fuse_layers.1.0.0.1.weight |         96 | 0.00MB
# backbone.stage4.1.fuse_layers.1.0.0.1.bias |         96 | 0.00MB
# backbone.stage4.1.fuse_layers.1.2.0.weight |      18432 | 0.07MB
# backbone.stage4.1.fuse_layers.1.2.1.weight |         96 | 0.00MB
# backbone.stage4.1.fuse_layers.1.2.1.bias |         96 | 0.00MB
# backbone.stage4.1.fuse_layers.1.3.0.weight |      36864 | 0.14MB
# backbone.stage4.1.fuse_layers.1.3.1.weight |         96 | 0.00MB
# backbone.stage4.1.fuse_layers.1.3.1.bias |         96 | 0.00MB
# backbone.stage4.1.fuse_layers.2.0.0.0.weight |      20736 | 0.08MB
# backbone.stage4.1.fuse_layers.2.0.0.1.weight |         48 | 0.00MB
# backbone.stage4.1.fuse_layers.2.0.0.1.bias |         48 | 0.00MB
# backbone.stage4.1.fuse_layers.2.0.1.0.weight |      82944 | 0.32MB
# backbone.stage4.1.fuse_layers.2.0.1.1.weight |        192 | 0.00MB
# backbone.stage4.1.fuse_layers.2.0.1.1.bias |        192 | 0.00MB
# backbone.stage4.1.fuse_layers.2.1.0.0.weight |     165888 | 0.63MB
# backbone.stage4.1.fuse_layers.2.1.0.1.weight |        192 | 0.00MB
# backbone.stage4.1.fuse_layers.2.1.0.1.bias |        192 | 0.00MB
# backbone.stage4.1.fuse_layers.2.3.0.weight |      73728 | 0.28MB
# backbone.stage4.1.fuse_layers.2.3.1.weight |        192 | 0.00MB
# backbone.stage4.1.fuse_layers.2.3.1.bias |        192 | 0.00MB
# backbone.stage4.1.fuse_layers.3.0.0.0.weight |      20736 | 0.08MB
# backbone.stage4.1.fuse_layers.3.0.0.1.weight |         48 | 0.00MB
# backbone.stage4.1.fuse_layers.3.0.0.1.bias |         48 | 0.00MB
# backbone.stage4.1.fuse_layers.3.0.1.0.weight |      20736 | 0.08MB
# backbone.stage4.1.fuse_layers.3.0.1.1.weight |         48 | 0.00MB
# backbone.stage4.1.fuse_layers.3.0.1.1.bias |         48 | 0.00MB
# backbone.stage4.1.fuse_layers.3.0.2.0.weight |     165888 | 0.63MB
# backbone.stage4.1.fuse_layers.3.0.2.1.weight |        384 | 0.00MB
# backbone.stage4.1.fuse_layers.3.0.2.1.bias |        384 | 0.00MB
# backbone.stage4.1.fuse_layers.3.1.0.0.weight |      82944 | 0.32MB
# backbone.stage4.1.fuse_layers.3.1.0.1.weight |         96 | 0.00MB
# backbone.stage4.1.fuse_layers.3.1.0.1.bias |         96 | 0.00MB
# backbone.stage4.1.fuse_layers.3.1.1.0.weight |     331776 | 1.27MB
# backbone.stage4.1.fuse_layers.3.1.1.1.weight |        384 | 0.00MB
# backbone.stage4.1.fuse_layers.3.1.1.1.bias |        384 | 0.00MB
# backbone.stage4.1.fuse_layers.3.2.0.0.weight |     663552 | 2.53MB
# backbone.stage4.1.fuse_layers.3.2.0.1.weight |        384 | 0.00MB
# backbone.stage4.1.fuse_layers.3.2.0.1.bias |        384 | 0.00MB
# backbone.stage4.2.branches.0.0.conv1.weight |      20736 | 0.08MB
# backbone.stage4.2.branches.0.0.bn1.weight |         48 | 0.00MB
# backbone.stage4.2.branches.0.0.bn1.bias |         48 | 0.00MB
# backbone.stage4.2.branches.0.0.conv2.weight |      20736 | 0.08MB
# backbone.stage4.2.branches.0.0.bn2.weight |         48 | 0.00MB
# backbone.stage4.2.branches.0.0.bn2.bias |         48 | 0.00MB
# backbone.stage4.2.branches.0.1.conv1.weight |      20736 | 0.08MB
# backbone.stage4.2.branches.0.1.bn1.weight |         48 | 0.00MB
# backbone.stage4.2.branches.0.1.bn1.bias |         48 | 0.00MB
# backbone.stage4.2.branches.0.1.conv2.weight |      20736 | 0.08MB
# backbone.stage4.2.branches.0.1.bn2.weight |         48 | 0.00MB
# backbone.stage4.2.branches.0.1.bn2.bias |         48 | 0.00MB
# backbone.stage4.2.branches.0.2.conv1.weight |      20736 | 0.08MB
# backbone.stage4.2.branches.0.2.bn1.weight |         48 | 0.00MB
# backbone.stage4.2.branches.0.2.bn1.bias |         48 | 0.00MB
# backbone.stage4.2.branches.0.2.conv2.weight |      20736 | 0.08MB
# backbone.stage4.2.branches.0.2.bn2.weight |         48 | 0.00MB
# backbone.stage4.2.branches.0.2.bn2.bias |         48 | 0.00MB
# backbone.stage4.2.branches.0.3.conv1.weight |      20736 | 0.08MB
# backbone.stage4.2.branches.0.3.bn1.weight |         48 | 0.00MB
# backbone.stage4.2.branches.0.3.bn1.bias |         48 | 0.00MB
# backbone.stage4.2.branches.0.3.conv2.weight |      20736 | 0.08MB
# backbone.stage4.2.branches.0.3.bn2.weight |         48 | 0.00MB
# backbone.stage4.2.branches.0.3.bn2.bias |         48 | 0.00MB
# backbone.stage4.2.branches.1.0.conv1.weight |      82944 | 0.32MB
# backbone.stage4.2.branches.1.0.bn1.weight |         96 | 0.00MB
# backbone.stage4.2.branches.1.0.bn1.bias |         96 | 0.00MB
# backbone.stage4.2.branches.1.0.conv2.weight |      82944 | 0.32MB
# backbone.stage4.2.branches.1.0.bn2.weight |         96 | 0.00MB
# backbone.stage4.2.branches.1.0.bn2.bias |         96 | 0.00MB
# backbone.stage4.2.branches.1.1.conv1.weight |      82944 | 0.32MB
# backbone.stage4.2.branches.1.1.bn1.weight |         96 | 0.00MB
# backbone.stage4.2.branches.1.1.bn1.bias |         96 | 0.00MB
# backbone.stage4.2.branches.1.1.conv2.weight |      82944 | 0.32MB
# backbone.stage4.2.branches.1.1.bn2.weight |         96 | 0.00MB
# backbone.stage4.2.branches.1.1.bn2.bias |         96 | 0.00MB
# backbone.stage4.2.branches.1.2.conv1.weight |      82944 | 0.32MB
# backbone.stage4.2.branches.1.2.bn1.weight |         96 | 0.00MB
# backbone.stage4.2.branches.1.2.bn1.bias |         96 | 0.00MB
# backbone.stage4.2.branches.1.2.conv2.weight |      82944 | 0.32MB
# backbone.stage4.2.branches.1.2.bn2.weight |         96 | 0.00MB
# backbone.stage4.2.branches.1.2.bn2.bias |         96 | 0.00MB
# backbone.stage4.2.branches.1.3.conv1.weight |      82944 | 0.32MB
# backbone.stage4.2.branches.1.3.bn1.weight |         96 | 0.00MB
# backbone.stage4.2.branches.1.3.bn1.bias |         96 | 0.00MB
# backbone.stage4.2.branches.1.3.conv2.weight |      82944 | 0.32MB
# backbone.stage4.2.branches.1.3.bn2.weight |         96 | 0.00MB
# backbone.stage4.2.branches.1.3.bn2.bias |         96 | 0.00MB
# backbone.stage4.2.branches.2.0.conv1.weight |     331776 | 1.27MB
# backbone.stage4.2.branches.2.0.bn1.weight |        192 | 0.00MB
# backbone.stage4.2.branches.2.0.bn1.bias |        192 | 0.00MB
# backbone.stage4.2.branches.2.0.conv2.weight |     331776 | 1.27MB
# backbone.stage4.2.branches.2.0.bn2.weight |        192 | 0.00MB
# backbone.stage4.2.branches.2.0.bn2.bias |        192 | 0.00MB
# backbone.stage4.2.branches.2.1.conv1.weight |     331776 | 1.27MB
# backbone.stage4.2.branches.2.1.bn1.weight |        192 | 0.00MB
# backbone.stage4.2.branches.2.1.bn1.bias |        192 | 0.00MB
# backbone.stage4.2.branches.2.1.conv2.weight |     331776 | 1.27MB
# backbone.stage4.2.branches.2.1.bn2.weight |        192 | 0.00MB
# backbone.stage4.2.branches.2.1.bn2.bias |        192 | 0.00MB
# backbone.stage4.2.branches.2.2.conv1.weight |     331776 | 1.27MB
# backbone.stage4.2.branches.2.2.bn1.weight |        192 | 0.00MB
# backbone.stage4.2.branches.2.2.bn1.bias |        192 | 0.00MB
# backbone.stage4.2.branches.2.2.conv2.weight |     331776 | 1.27MB
# backbone.stage4.2.branches.2.2.bn2.weight |        192 | 0.00MB
# backbone.stage4.2.branches.2.2.bn2.bias |        192 | 0.00MB
# backbone.stage4.2.branches.2.3.conv1.weight |     331776 | 1.27MB
# backbone.stage4.2.branches.2.3.bn1.weight |        192 | 0.00MB
# backbone.stage4.2.branches.2.3.bn1.bias |        192 | 0.00MB
# backbone.stage4.2.branches.2.3.conv2.weight |     331776 | 1.27MB
# backbone.stage4.2.branches.2.3.bn2.weight |        192 | 0.00MB
# backbone.stage4.2.branches.2.3.bn2.bias |        192 | 0.00MB
# backbone.stage4.2.branches.3.0.conv1.weight |    1327104 | 5.06MB
# backbone.stage4.2.branches.3.0.bn1.weight |        384 | 0.00MB
# backbone.stage4.2.branches.3.0.bn1.bias |        384 | 0.00MB
# backbone.stage4.2.branches.3.0.conv2.weight |    1327104 | 5.06MB
# backbone.stage4.2.branches.3.0.bn2.weight |        384 | 0.00MB
# backbone.stage4.2.branches.3.0.bn2.bias |        384 | 0.00MB
# backbone.stage4.2.branches.3.1.conv1.weight |    1327104 | 5.06MB
# backbone.stage4.2.branches.3.1.bn1.weight |        384 | 0.00MB
# backbone.stage4.2.branches.3.1.bn1.bias |        384 | 0.00MB
# backbone.stage4.2.branches.3.1.conv2.weight |    1327104 | 5.06MB
# backbone.stage4.2.branches.3.1.bn2.weight |        384 | 0.00MB
# backbone.stage4.2.branches.3.1.bn2.bias |        384 | 0.00MB
# backbone.stage4.2.branches.3.2.conv1.weight |    1327104 | 5.06MB
# backbone.stage4.2.branches.3.2.bn1.weight |        384 | 0.00MB
# backbone.stage4.2.branches.3.2.bn1.bias |        384 | 0.00MB
# backbone.stage4.2.branches.3.2.conv2.weight |    1327104 | 5.06MB
# backbone.stage4.2.branches.3.2.bn2.weight |        384 | 0.00MB
# backbone.stage4.2.branches.3.2.bn2.bias |        384 | 0.00MB
# backbone.stage4.2.branches.3.3.conv1.weight |    1327104 | 5.06MB
# backbone.stage4.2.branches.3.3.bn1.weight |        384 | 0.00MB
# backbone.stage4.2.branches.3.3.bn1.bias |        384 | 0.00MB
# backbone.stage4.2.branches.3.3.conv2.weight |    1327104 | 5.06MB
# backbone.stage4.2.branches.3.3.bn2.weight |        384 | 0.00MB
# backbone.stage4.2.branches.3.3.bn2.bias |        384 | 0.00MB
# backbone.stage4.2.fuse_layers.0.1.0.weight |       4608 | 0.02MB
# backbone.stage4.2.fuse_layers.0.1.1.weight |         48 | 0.00MB
# backbone.stage4.2.fuse_layers.0.1.1.bias |         48 | 0.00MB
# backbone.stage4.2.fuse_layers.0.2.0.weight |       9216 | 0.04MB
# backbone.stage4.2.fuse_layers.0.2.1.weight |         48 | 0.00MB
# backbone.stage4.2.fuse_layers.0.2.1.bias |         48 | 0.00MB
# backbone.stage4.2.fuse_layers.0.3.0.weight |      18432 | 0.07MB
# backbone.stage4.2.fuse_layers.0.3.1.weight |         48 | 0.00MB
# backbone.stage4.2.fuse_layers.0.3.1.bias |         48 | 0.00MB
# backbone.stage4.2.fuse_layers.1.0.0.0.weight |      41472 | 0.16MB
# backbone.stage4.2.fuse_layers.1.0.0.1.weight |         96 | 0.00MB
# backbone.stage4.2.fuse_layers.1.0.0.1.bias |         96 | 0.00MB
# backbone.stage4.2.fuse_layers.1.2.0.weight |      18432 | 0.07MB
# backbone.stage4.2.fuse_layers.1.2.1.weight |         96 | 0.00MB
# backbone.stage4.2.fuse_layers.1.2.1.bias |         96 | 0.00MB
# backbone.stage4.2.fuse_layers.1.3.0.weight |      36864 | 0.14MB
# backbone.stage4.2.fuse_layers.1.3.1.weight |         96 | 0.00MB
# backbone.stage4.2.fuse_layers.1.3.1.bias |         96 | 0.00MB
# backbone.stage4.2.fuse_layers.2.0.0.0.weight |      20736 | 0.08MB
# backbone.stage4.2.fuse_layers.2.0.0.1.weight |         48 | 0.00MB
# backbone.stage4.2.fuse_layers.2.0.0.1.bias |         48 | 0.00MB
# backbone.stage4.2.fuse_layers.2.0.1.0.weight |      82944 | 0.32MB
# backbone.stage4.2.fuse_layers.2.0.1.1.weight |        192 | 0.00MB
# backbone.stage4.2.fuse_layers.2.0.1.1.bias |        192 | 0.00MB
# backbone.stage4.2.fuse_layers.2.1.0.0.weight |     165888 | 0.63MB
# backbone.stage4.2.fuse_layers.2.1.0.1.weight |        192 | 0.00MB
# backbone.stage4.2.fuse_layers.2.1.0.1.bias |        192 | 0.00MB
# backbone.stage4.2.fuse_layers.2.3.0.weight |      73728 | 0.28MB
# backbone.stage4.2.fuse_layers.2.3.1.weight |        192 | 0.00MB
# backbone.stage4.2.fuse_layers.2.3.1.bias |        192 | 0.00MB
# backbone.stage4.2.fuse_layers.3.0.0.0.weight |      20736 | 0.08MB
# backbone.stage4.2.fuse_layers.3.0.0.1.weight |         48 | 0.00MB
# backbone.stage4.2.fuse_layers.3.0.0.1.bias |         48 | 0.00MB
# backbone.stage4.2.fuse_layers.3.0.1.0.weight |      20736 | 0.08MB
# backbone.stage4.2.fuse_layers.3.0.1.1.weight |         48 | 0.00MB
# backbone.stage4.2.fuse_layers.3.0.1.1.bias |         48 | 0.00MB
# backbone.stage4.2.fuse_layers.3.0.2.0.weight |     165888 | 0.63MB
# backbone.stage4.2.fuse_layers.3.0.2.1.weight |        384 | 0.00MB
# backbone.stage4.2.fuse_layers.3.0.2.1.bias |        384 | 0.00MB
# backbone.stage4.2.fuse_layers.3.1.0.0.weight |      82944 | 0.32MB
# backbone.stage4.2.fuse_layers.3.1.0.1.weight |         96 | 0.00MB
# backbone.stage4.2.fuse_layers.3.1.0.1.bias |         96 | 0.00MB
# backbone.stage4.2.fuse_layers.3.1.1.0.weight |     331776 | 1.27MB
# backbone.stage4.2.fuse_layers.3.1.1.1.weight |        384 | 0.00MB
# backbone.stage4.2.fuse_layers.3.1.1.1.bias |        384 | 0.00MB
# backbone.stage4.2.fuse_layers.3.2.0.0.weight |     663552 | 2.53MB
# backbone.stage4.2.fuse_layers.3.2.0.1.weight |        384 | 0.00MB
# backbone.stage4.2.fuse_layers.3.2.0.1.bias |        384 | 0.00MB
# ocr.conv3x3_ocr.0.weight               |    3317760 | 12.66MB
# ocr.conv3x3_ocr.0.bias                 |        512 | 0.00MB
# ocr.conv3x3_ocr.1.0.weight             |        512 | 0.00MB
# ocr.conv3x3_ocr.1.0.bias               |        512 | 0.00MB
# ocr.ocr_distri_head.object_context_block.f_pixel.0.weight |     131072 | 0.50MB
# ocr.ocr_distri_head.object_context_block.f_pixel.1.0.weight |        256 | 0.00MB
# ocr.ocr_distri_head.object_context_block.f_pixel.1.0.bias |        256 | 0.00MB
# ocr.ocr_distri_head.object_context_block.f_pixel.2.weight |      65536 | 0.25MB
# ocr.ocr_distri_head.object_context_block.f_pixel.3.0.weight |        256 | 0.00MB
# ocr.ocr_distri_head.object_context_block.f_pixel.3.0.bias |        256 | 0.00MB
# ocr.ocr_distri_head.object_context_block.f_object.0.weight |     131072 | 0.50MB
# ocr.ocr_distri_head.object_context_block.f_object.1.0.weight |        256 | 0.00MB
# ocr.ocr_distri_head.object_context_block.f_object.1.0.bias |        256 | 0.00MB
# ocr.ocr_distri_head.object_context_block.f_object.2.weight |      65536 | 0.25MB
# ocr.ocr_distri_head.object_context_block.f_object.3.0.weight |        256 | 0.00MB
# ocr.ocr_distri_head.object_context_block.f_object.3.0.bias |        256 | 0.00MB
# ocr.ocr_distri_head.object_context_block.f_down.0.weight |     131072 | 0.50MB
# ocr.ocr_distri_head.object_context_block.f_down.1.0.weight |        256 | 0.00MB
# ocr.ocr_distri_head.object_context_block.f_down.1.0.bias |        256 | 0.00MB
# ocr.ocr_distri_head.object_context_block.f_up.0.weight |     131072 | 0.50MB
# ocr.ocr_distri_head.object_context_block.f_up.1.0.weight |        512 | 0.00MB
# ocr.ocr_distri_head.object_context_block.f_up.1.0.bias |        512 | 0.00MB
# ocr.ocr_distri_head.conv_bn_dropout.0.weight |     524288 | 2.00MB
# ocr.ocr_distri_head.conv_bn_dropout.1.0.weight |        512 | 0.00MB
# ocr.ocr_distri_head.conv_bn_dropout.1.0.bias |        512 | 0.00MB
# ocr.cls_head.weight                    |      10240 | 0.04MB
# ocr.cls_head.bias                      |         20 | 0.00MB
# ocr.aux_head.0.weight                  |     518400 | 1.98MB
# ocr.aux_head.0.bias                    |        720 | 0.00MB
# ocr.aux_head.1.0.weight                |        720 | 0.00MB
# ocr.aux_head.1.0.bias                  |        720 | 0.00MB
# ocr.aux_head.2.weight                  |      14400 | 0.05MB
# ocr.aux_head.2.bias                    |         20 | 0.00MB
# scale_attn.conv0.weight                |    1179648 | 4.50MB
# scale_attn.bn0.weight                  |        256 | 0.00MB
# scale_attn.bn0.bias                    |        256 | 0.00MB
# scale_attn.conv1.weight                |     589824 | 2.25MB
# scale_attn.bn1.weight                  |        256 | 0.00MB
# scale_attn.bn1.bias                    |        256 | 0.00MB
# scale_attn.conv2.weight                |        256 | 0.00MB
# crf.smoothness_weight                  |          1 | 0.00MB
# crf.inv_smoothness_theta               |          2 | 0.00MB
# --------------------------------------------------------------------
# Total size: 275.58MB
# ====================================================================

# %%
import signal
from abc import ABC, abstractmethod
from datetime import datetime
from sklearn.metrics import cohen_kappa_score, f1_score, jaccard_score
from torch import optim
from tqdm import tqdm

class AveragePerBatchMetric():
    def __init__(self, criteria):
        self.criteria = criteria
        self.values = []
    
    @abstractmethod
    def append(self, y_hat, y):
        pass

    @abstractmethod
    def get(self):
        mean = np.mean(self.values)
        self.values = []
        return mean

stop = False
def handler(sig, frame):
    global stop
    if not stop:
        print("stopping next training iteration")
    stop = True

def stop_callback():
    signal.signal(signal.SIGINT, handler)

def train_one_epoch(
    model,
    dataloader,
    loss_fn,
    optimizer,
    device,
    use_amp,
    max_norm
    ):
    model.train()
    start_time = datetime.now()

    scaler = torch.cuda.amp.GradScaler()
    losses = []
    for x, y in tqdm(dataloader, desc="train batches", leave=False, position=0):
        if device is not None:
            x = x.to(device)
            y = y.to(device)

        with torch.autocast(device_type=device, dtype=torch.float16, enabled=use_amp):
            _, _, loss = model({ 'images': x, 'gts': y })
            #loss = loss_fn(y_hat, y)

        loss_val = loss.item()
        losses.append(loss_val)
        scaler.scale(loss).backward()

        scaler.unscale_(optimizer)
        nn.utils.clip_grad_norm_(model.parameters(), max_norm)

        scaler.step(optimizer)
        scaler.update()
            
        optimizer.zero_grad(set_to_none=True)
    
    end_time = datetime.now()
    timespan = end_time - start_time

    return (timespan, losses)

@torch.no_grad
def test_one_epoch(model, dataloader, loss_fn, metrics, device):
    model.eval()
    start_time = datetime.now()

    losses = []
    for x, y in tqdm(dataloader, desc="test batches", leave=False, position=0):
        if device is not None:
            x = x.to(device)
            y = y.to(device)
        
        y_hat = model({ 'images': x, 'gts': y })

        loss = loss_fn(y_hat['pred'], y)
        losses.append(loss.item())
        
        for key in metrics:
            metrics[key].append(y_hat['pred'], y)
    
    end_time = datetime.now()
    timespan = end_time - start_time

    return (timespan, losses)

def train(
    model,
    dataloader,
    loss_fn,
    optimizer,
    scheduler,
    metrics,
    device,
    epochs,
    test_interval=4,
    checkpoints=5,
    checkpoints_dir=None,
    report_interval=1,
    use_amp=True,
    max_norm=0.1
    ):
    metrics_history = {
        'train': {},
        'test': {
            key: ([]) for key in metrics['test']
        }
    }
    metrics_history['train']['loss'] = []
    metrics_history['test']['loss'] = []

    def save_checkpoint(epoch, model, optimizer, checkpoints_dir=None):
        checkpoint_path = f"checkpoint_pastis.pth"
        if checkpoints_dir is not None:
            checkpoint_path = os.path.join(checkpoints_dir, checkpoint_path)
        print(f"saving checkpoint {checkpoint_path}")
        torch.save(
            {
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict()
            },
            checkpoint_path
            )

    model.to(device)
    for epoch in range(1, epochs + 1):
        if stop:
            break

        timespan, losses = train_one_epoch(
            model,
            dataloader['train'],
            loss_fn,
            optimizer,
            device,
            use_amp,
            max_norm
        )
        print(
            f"==============================================\n"
            f"EPOCH {epoch:4d}\n"
            "train results:"
            )
        tloss = np.mean(losses)
        metrics_history['train']['loss'].append(tloss)
        print(
            f"\ttimespan: {timespan}\n"
            f"\tloss: {tloss:.4f}"
            )

        if epoch % test_interval == 0:
            timespan, losses = test_one_epoch(
                model,
                dataloader['test'],
                loss_fn,
                metrics['test'],
                device
                )
            vloss = np.mean(losses)
            metrics_history['test']['loss'].append(vloss)
            print(
                "test results:\n"
                f"\ttimespan: {timespan}\n"
                f"\tloss: {np.mean(losses):.4f}"
                )
            for key in metrics['test']:
                score = metrics['test'][key].get()
                metrics_history['test'][key].append(score)
                print(f"\t{key}: {score:.4f}")

        scheduler.step()

        if checkpoints is not None and epoch % checkpoints == 0:
            save_checkpoint(epoch, model, optimizer, checkpoints_dir)

    return metrics_history

# %%
class AverageJaccard(AveragePerBatchMetric):
    def __init__(self):
        super().__init__(jaccard_score)

    def append(self, y_hat, y):
        target = y.flatten().cpu().to(torch.long).numpy()
        y_hat = torch.argmax(y_hat, dim=1)
        pred = y_hat.flatten().cpu().to(torch.long).numpy()
        acc = self.criteria(target, pred, average='macro')
        self.values.append(acc)

class AverageF1Score(AveragePerBatchMetric):
    def __init__(self):
        super().__init__(f1_score)

    def append(self, y_hat, y):
        target = y.flatten().cpu().to(torch.long).numpy()
        y_hat = torch.argmax(y_hat, dim=1)
        pred = y_hat.flatten().cpu().to(torch.long).numpy()
        acc = self.criteria(target, pred, average='macro')
        self.values.append(acc)

class AverageCohenKappa(AveragePerBatchMetric):
    def __init__(self):
        super().__init__(cohen_kappa_score)

    def append(self, y_hat, y):
        target = y.flatten().cpu().to(torch.long).numpy()
        y_hat = torch.argmax(y_hat, dim=1)
        pred = y_hat.flatten().cpu().to(torch.long).numpy()
        acc = self.criteria(target, pred)
        self.values.append(acc)

# %%
import warnings

stop_callback()

#torch.autograd.set_detect_anomaly(True)
torch.use_deterministic_algorithms(True, warn_only=True)
torch.backends.cudnn.benchmark = True

loss_fn = nn.CrossEntropyLoss(
    weight=classes_weights.to(backend_device)
    )
optimizer = optim.Adam(params=hrnet_model.parameters(), lr=1e-4)
#scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.5)
#scheduler = optim.lr_scheduler.PolynomialLR(optimizer, total_iters=60, power=2.0)
# TEST: PolynomialLR(optimizer, total_iters=4, power=1.0)
scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.891251)
metrics = {
    #'train': { 'jaccard': AverageJaccard(), 'f1_score': AverageF1Score(), 'cohen_kappa': AverageCohenKappa() },
    'test': {
        'jaccard': AverageJaccard(),
        'f1_score': AverageF1Score(),
        'cohen_kappa': AverageCohenKappa()
    }
}

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    results = train(
        hrnet_model,
        pastis_dataloader,
        loss_fn,
        optimizer,
        scheduler,
        metrics,
        backend_device,
        60,
        checkpoints=10,
        report_interval=1
        )
# Out:
# ==============================================
# EPOCH    1
# train results:
# ==============================================
# EPOCH    2
# train results:
# ==============================================
# EPOCH    3
# train results:
# ==============================================
# EPOCH    4
# train results:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 28
#      26 with warnings.catch_warnings():
#      27     warnings.simplefilter("ignore")
# ---> 28     results = train(
#      29         hrnet_model,
#      30         pastis_dataloader,
#      31         loss_fn,
#      32         optimizer,
#      33         scheduler,
#      34         metrics,
#      35         backend_device,
#      36         60,
#      37         checkpoints=10,
#      38         report_interval=1
#      39         )
#
# Cell In[14], line 163, in train(model, dataloader, loss_fn, optimizer, scheduler, metrics, device, epochs, test_interval, checkpoints, checkpoints_dir, report_interval, use_amp, max_norm)
#     155 #tloss = np.mean(losses)
#     156 #metrics_history['train']['loss'].append(tloss)
#     157 #print(
#     158 #    f"\ttimespan: {timespan}\n"
#     159 #    f"\tloss: {tloss:.4f}"
#     160 #    )
#     162 if epoch % test_interval == 0:
# --> 163     timespan, losses = test_one_epoch(
#     164         model,
#     165         dataloader['test'],
#     166         loss_fn,
#     167         metrics['test'],
#     168         device
#     169         )
#     170     vloss = np.mean(losses)
#     171     metrics_history['test']['loss'].append(vloss)
#
# File /opt/conda/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# Cell In[14], line 84, in test_one_epoch(model, dataloader, loss_fn, metrics, device)
#      81     x = x.to(device)
#      82     y = y.to(device)
# ---> 84 y_hat = model({ 'images': x, 'gts': y })
#      86 loss = loss_fn(y_hat['pred'], y)
#      87 losses.append(loss.item())
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /homeLocal/jpulzdeoliveira/notebooks/HRNet/models/ocrnet.py:386, in MscaleOCR.forward(self, inputs, feats)
#     383 if cfg.MODEL.N_SCALES and not self.training:
#     384     return self.nscale_forward(inputs, cfg.MODEL.N_SCALES)
# --> 386 return self.two_scale_forward(inputs, feats=feats)
#
# File /homeLocal/jpulzdeoliveira/notebooks/HRNet/models/ocrnet.py:328, in MscaleOCR.two_scale_forward(self, inputs, feats)
#     326     hi_outs, features = self._fwd(x_1x, feats=feats)
#     327 else:
# --> 328     hi_outs = self._fwd(x_1x, feats=feats)
#     329 pred_10x = hi_outs['cls_out']
#     330 p_1x = pred_10x
#
# File /homeLocal/jpulzdeoliveira/notebooks/HRNet/models/ocrnet.py:206, in MscaleOCR._fwd(self, x, feats)
#     203 x_size = x.size()[2:]
#     205 _, _, high_level_features = self.backbone(x)
# --> 206 cls_out, aux_out, ocr_mid_feats = self.ocr(high_level_features)
#     207 attn = self.scale_attn(ocr_mid_feats)
#     209 aux_out = Upsample(aux_out, x_size)
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /homeLocal/jpulzdeoliveira/notebooks/HRNet/models/ocrnet.py:88, in OCR_block.forward(self, high_level_features)
#      86 aux_out = self.aux_head(high_level_features)
#      87 context = self.ocr_gather_head(feats, aux_out)
# ---> 88 ocr_feats = self.ocr_distri_head(feats, context)
#      89 cls_out = self.cls_head(ocr_feats)
#      90 return cls_out, aux_out, ocr_feats
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /homeLocal/jpulzdeoliveira/notebooks/HRNet/models/ocr_utils.py:150, in SpatialOCR_Module.forward(self, feats, proxy_feats)
#     149 def forward(self, feats, proxy_feats):
# --> 150     context = self.object_context_block(feats, proxy_feats)
#     152     if cfg.MODEL.OCR_ASPP:
#     153         aspp = self.aspp(feats)
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /homeLocal/jpulzdeoliveira/notebooks/HRNet/models/ocr_utils.py:100, in ObjectAttentionBlock.forward(self, x, proxy)
#      97 if self.scale > 1:
#      98     x = self.pool(x)
# --> 100 query = self.f_pixel(x).view(batch_size, self.key_channels, -1)
#     101 query = query.permute(0, 2, 1)
#     102 key = self.f_object(proxy).view(batch_size, self.key_channels, -1)
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/conv.py:460, in Conv2d.forward(self, input)
#     459 def forward(self, input: Tensor) -> Tensor:
# --> 460     return self._conv_forward(input, self.weight, self.bias)
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/conv.py:456, in Conv2d._conv_forward(self, input, weight, bias)
#     452 if self.padding_mode != 'zeros':
#     453     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     454                     weight, bias, self.stride,
#     455                     _pair(0), self.dilation, self.groups)
# --> 456 return F.conv2d(input, weight, bias, self.stride,
#     457                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:

# %%
model_save_path = os.path.join("/homeLocal/jpulzdeoliveira/models/PASTIS-hrnet.pth")
torch.save(hrnet_model.state_dict(), model_save_path)

# %%
model_save_path = os.path.join("/homeLocal/jpulzdeoliveira/models/PASTIS-hrnet.pth")
hrnet_model.load_state_dict(torch.load(model_save_path))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[15], line 2
#       1 model_save_path = os.path.join("/homeLocal/jpulzdeoliveira/models/PASTIS-hrnet.pth")
# ----> 2 hrnet_model.load_state_dict(torch.load(model_save_path))
#
# File /opt/conda/lib/python3.10/site-packages/torch/serialization.py:1026, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1024             except RuntimeError as e:
#    1025                 raise pickle.UnpicklingError(UNSAFE_MESSAGE + str(e)) from None
# -> 1026         return _load(opened_zipfile,
#    1027                      map_location,
#    1028                      pickle_module,
#    1029                      overall_storage=overall_storage,
#    1030                      **pickle_load_args)
#    1031 if mmap:
#    1032     raise RuntimeError("mmap can only be used with files saved with "
#    1033                        "`torch.save(_use_new_zipfile_serialization=True), "
#    1034                        "please torch.save your checkpoint with this option in order to use mmap.")
#
# File /opt/conda/lib/python3.10/site-packages/torch/serialization.py:1438, in _load(zip_file, map_location, pickle_module, pickle_file, overall_storage, **pickle_load_args)
#    1436 unpickler = UnpicklerWrapper(data_file, **pickle_load_args)
#    1437 unpickler.persistent_load = persistent_load
# -> 1438 result = unpickler.load()
#    1440 torch._utils._validate_loaded_sparse_tensors()
#    1441 torch._C._log_api_usage_metadata(
#    1442     "torch.load.metadata", {"serialization_id": zip_file.serialization_id()}
#    1443 )
#
# File /opt/conda/lib/python3.10/site-packages/torch/serialization.py:1408, in _load.<locals>.persistent_load(saved_id)
#    1406 else:
#    1407     nbytes = numel * torch._utils._element_size(dtype)
# -> 1408     typed_storage = load_tensor(dtype, nbytes, key, _maybe_decode_ascii(location))
#    1410 return typed_storage
#
# File /opt/conda/lib/python3.10/site-packages/torch/serialization.py:1382, in _load.<locals>.load_tensor(dtype, numel, key, location)
#    1377         storage.byteswap(dtype)
#    1379 # TODO: Once we decide to break serialization FC, we can
#    1380 # stop wrapping with TypedStorage
#    1381 typed_storage = torch.storage.TypedStorage(
# -> 1382     wrap_storage=restore_location(storage, location),
#    1383     dtype=dtype,
#    1384     _internal=True)
#    1386 if typed_storage._data_ptr() != 0:
#    1387     loaded_storages[key] = typed_storage
#
# File /opt/conda/lib/python3.10/site-packages/torch/serialization.py:391, in default_restore_location(storage, location)
#     389 def default_restore_location(storage, location):
#     390     for _, _, fn in _package_registry:
# --> 391         result = fn(storage, location)
#     392         if result is not None:
#     393             return result
#
# File /opt/conda/lib/python3.10/site-packages/torch/serialization.py:266, in _cuda_deserialize(obj, location)
#     264 def _cuda_deserialize(obj, location):
#     265     if location.startswith('cuda'):
# --> 266         device = validate_cuda_device(location)
#     267         if getattr(obj, "_torch_load_uninitialized", False):
#     268             with torch.cuda.device(device):
#
# File /opt/conda/lib/python3.10/site-packages/torch/serialization.py:250, in validate_cuda_device(location)
#     247 device = torch.cuda._utils._get_device_index(location, True)
#     249 if not torch.cuda.is_available():
# --> 250     raise RuntimeError('Attempting to deserialize object on a CUDA '
#     251                        'device but torch.cuda.is_available() is False. '
#     252                        'If you are running on a CPU-only machine, '
#     253                        'please use torch.load with map_location=torch.device(\'cpu\') '
#     254                        'to map your storages to the CPU.')
#     255 device_count = torch.cuda.device_count()
#     256 if device >= device_count:
#
# RuntimeError: Attempting to deserialize object on a CUDA device but torch.cuda.is_available() is False. If you are running on a CPU-only machine, please use torch.load with map_location=torch.device('cpu') to map your storages to the CPU.

# %%
from matplotlib.colors import ListedColormap

cm = mtp.colormaps["tab20"]
def_colors = cm.colors
cus_colors = ['k'] + [def_colors[i] for i in range(1, 20)] + ['w']
cmap = ListedColormap(colors=cus_colors, name="agri", N=21)

def get_input_rgb(x):
    im = x[[2, 1, 0]].cpu().numpy()
    mx = im.max(axis=(1, 2))
    mi = im.min(axis=(1, 2))
    im = (im - mi[:, None, None]) / (mx - mi)[:, None, None]
    im = im.swapaxes(0, 2).swapaxes(0, 1)
    im = np.clip(im, a_max=1, a_min=0)
    return im

def plot_test(x, y, y_hat):
    fix, axes = plt.subplots(1, 3, figsize=(20, 20))
    axes[0].imshow(get_input_rgb(x))
    axes[1].imshow(y.squeeze(), cmap=cmap, vmin=0, vmax=20)
    axes[2].imshow(y_hat.squeeze(), cmap=cmap, vmin=0, vmax=20)

tx, ty = dataset[np.random.randint(len(dataset))]

hrnet_model.to("cpu")

#!cd test_results && rm -rf plot-*
test_results_dir = os.path.join("./", "test_results")
hrnet_model.eval()
jaccard = AverageJaccard()
ranges = (
    (3, 3, 0),
    (3, 3, 1),
    (3, 3, 2),
    (5, 3, 0),
    (5, 3, 1),
    (5, 3, 2),
)
accuracies = []
with torch.no_grad():
    for x, y in tqdm(
        pastis_dataloader['val'],
        leave=False,
        position=0
        ):
        for c, i, s in ranges:
            mx = get_median(x, c, i, s)
            for j in range(mx.size(0)):
                for k in range(mx.size(1)):
                    tx = mx[j:j+1, k]
                    ty = y[j:j+1]
                    tx, ty = augment(tx, ty)
                    ty_hat = hrnet_model({'images': tx, 'gts': ty})
                    ty_hat = ty_hat['pred']
                    jaccard.append(ty_hat, ty)
                    ty_hat = torch.argmax(ty_hat, dim=1).squeeze(0).detach()

                    plt.figure(num=1, clear=True)
                    plot_test(tx.squeeze(0), ty.squeeze(0), ty_hat)
                    acc = jaccard.get()
                    accuracies.append(acc)
                    plt.title(acc)
                    plt.savefig(os.path.join(
                        test_results_dir,
                        f"plot-{acc * 10:.2f}{i * x.size(0) + j}.png"
                        ), bbox_inches='tight')
                    #plt.show()
                    plt.close("all")
                    plt.close()

print(f"\nvalidation average accuracy: {np.mean(accuracies)}")
# Out:
#  50%|██████████████████████████████████████████                                          | 2/4 [26:39<26:34, 797.37s/it]
